# %%
import music21
import pandas as pd
import os
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('dataset.csv')

# %%
chunks = list(sorted(set(df.file.to_list())))

# %%
SOPRANO_MIN = 57
SOPRANO_MAX = 81

ALTO_MIN = 52
ALTO_MAX = 74

TENOR_MIN = 48
TENOR_MAX = 69

BASS_MIN = 36
BASS_MAX = 64

ranges = {
    'soprano': {midinumber: (midinumber - SOPRANO_MIN + 1) for midinumber in range(SOPRANO_MIN, SOPRANO_MAX + 1)},
    'alto': {midinumber: (midinumber - ALTO_MIN + 1) for midinumber in range(ALTO_MIN, ALTO_MAX + 1)},
    'tenor': {midinumber: (midinumber - TENOR_MIN + 1) for midinumber in range(TENOR_MIN, TENOR_MAX + 1)},
    'bass': {midinumber: (midinumber - BASS_MIN + 1) for midinumber in range(BASS_MIN, BASS_MAX + 1)},
}

for part, notes in ranges.items():
    print(f'the {part} has a range of {len(notes)} notes (plus the "hold" symbol)')
# Out:
# the soprano has a range of 25 notes (plus the "hold" symbol)
# the alto has a range of 23 notes (plus the "hold" symbol)
# the tenor has a range of 22 notes (plus the "hold" symbol)
# the bass has a range of 29 notes (plus the "hold" symbol)

# %%
def encode_note(n, rang):
    if n == '--' or n == 'Rest':
        ret = 0
    else:
        note = music21.note.Note(n)
        ret = ranges[rang][note.pitch.midi]
    return ret

def one_hot_encode(idx, rang):
    length = len(ranges[rang].values())
    ret = [0] * (length + 1)
    ret[idx] = 1
    return ret

# %%
x = []
y = []
for chunk in chunks:
    print(f'Procesing {chunk}...')
    dfchunk = df[df.file == chunk]    
    s = dfchunk.soprano.apply(encode_note, args=('soprano',)) 
    xi = np.array([[one_hot_encode(idx, 'soprano') for idx in s]])    
    xi = xi.reshape(-1)    
    a = dfchunk.alto.apply(encode_note, args=('alto',))
    t = dfchunk.tenor.apply(encode_note, args=('tenor',))
    b = dfchunk.bass.apply(encode_note, args=('bass',))    
    ya = np.array([one_hot_encode(idx, 'alto') for idx in a])
    yt = np.array([one_hot_encode(idx, 'tenor') for idx in t])
    yb = np.array([one_hot_encode(idx, 'bass') for idx in b])  
    yi = np.concatenate((ya, yt, yb), axis=None)        
    x.append(xi)
    y.append(yi)
# Out:
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_0...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_1...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_10...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_11...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_12...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_2...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_3...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_4...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_5...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_6...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_7...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_8...
# Procesing 113. Ihr Gestirn', ihr hohen L\u3fte_chunk_9...
# Procesing 25. Christ lag in Todesbanden_chunk_0...
# Procesing 25. Christ lag in Todesbanden_chunk_1...
# Procesing 25. Christ lag in Todesbanden_chunk_2...
# Procesing 25. Christ lag in Todesbanden_chunk_3...
# Procesing 25. Christ lag in Todesbanden_chunk_4...
# Procesing 25. Christ lag in Todesbanden_chunk_5...
# Procesing 25. Christ lag in Todesbanden_chunk_6...
# Procesing 25. Christ lag in Todesbanden_chunk_7...
# Procesing 25. Christ lag in Todesbanden_chunk_8...
# Procesing 28. Christus, der ist mein Leben_chunk_0...
# Procesing 28. Christus, der ist mein Leben_chunk_1...
# Procesing 28. Christus, der ist mein Leben_chunk_2...
# Procesing 28. Christus, der ist mein Leben_chunk_3...
# Procesing 28. Christus, der ist mein Leben_chunk_4...
# Procesing bwv10.7.mxl_chunk_0...
# Procesing bwv10.7.mxl_chunk_1...
# Procesing bwv10.7.mxl_chunk_10...
# Procesing bwv10.7.mxl_chunk_11...
# Procesing bwv10.7.mxl_chunk_12...
# Procesing bwv10.7.mxl_chunk_13...
# Procesing bwv10.7.mxl_chunk_14...
# Procesing bwv10.7.mxl_chunk_15...
# Procesing bwv10.7.mxl_chunk_16...
# Procesing bwv10.7.mxl_chunk_17...
# Procesing bwv10.7.mxl_chunk_18...
# Procesing bwv10.7.mxl_chunk_2...
# Procesing bwv10.7.mxl_chunk_3...
# Procesing bwv10.7.mxl_chunk_4...
# Procesing bwv10.7.mxl_chunk_5...
# Procesing bwv10.7.mxl_chunk_6...
# Procesing bwv10.7.mxl_chunk_7...
# Procesing bwv10.7.mxl_chunk_8...
# Procesing bwv10.7.mxl_chunk_9...
# Procesing bwv101.7.mxl_chunk_0...
# Procesing bwv101.7.mxl_chunk_1...
# Procesing bwv101.7.mxl_chunk_10...
# Procesing bwv101.7.mxl_chunk_2...
# Procesing bwv101.7.mxl_chunk_3...
# Procesing bwv101.7.mxl_chunk_4...
# Procesing bwv101.7.mxl_chunk_5...
# Procesing bwv101.7.mxl_chunk_6...
# Procesing bwv101.7.mxl_chunk_7...
# Procesing bwv101.7.mxl_chunk_8...
# Procesing bwv101.7.mxl_chunk_9...
# Procesing bwv102.7.mxl_chunk_0...
# Procesing bwv102.7.mxl_chunk_1...
# Procesing bwv102.7.mxl_chunk_10...
# Procesing bwv102.7.mxl_chunk_2...
# Procesing bwv102.7.mxl_chunk_3...
# Procesing bwv102.7.mxl_chunk_4...
# Procesing bwv102.7.mxl_chunk_5...
# Procesing bwv102.7.mxl_chunk_6...
# Procesing bwv102.7.mxl_chunk_7...
# Procesing bwv102.7.mxl_chunk_8...
# Procesing bwv102.7.mxl_chunk_9...
# Procesing bwv103.6.mxl_chunk_0...
# Procesing bwv103.6.mxl_chunk_1...
# Procesing bwv103.6.mxl_chunk_10...
# Procesing bwv103.6.mxl_chunk_2...
# Procesing bwv103.6.mxl_chunk_3...
# Procesing bwv103.6.mxl_chunk_4...
# Procesing bwv103.6.mxl_chunk_5...
# Procesing bwv103.6.mxl_chunk_6...
# Procesing bwv103.6.mxl_chunk_7...
# Procesing bwv103.6.mxl_chunk_8...
# Procesing bwv103.6.mxl_chunk_9...
# Procesing bwv104.6.mxl_chunk_0...
# Procesing bwv104.6.mxl_chunk_1...
# Procesing bwv104.6.mxl_chunk_2...
# Procesing bwv104.6.mxl_chunk_3...
# Procesing bwv104.6.mxl_chunk_4...
# Procesing bwv104.6.mxl_chunk_5...
# Procesing bwv104.6.mxl_chunk_6...
# Procesing bwv104.6.mxl_chunk_7...
# Procesing bwv108.6.mxl_chunk_0...
# Procesing bwv108.6.mxl_chunk_1...
# Procesing bwv108.6.mxl_chunk_10...
# Procesing bwv108.6.mxl_chunk_11...
# Procesing bwv108.6.mxl_chunk_2...
# Procesing bwv108.6.mxl_chunk_3...
# Procesing bwv108.6.mxl_chunk_4...
# Procesing bwv108.6.mxl_chunk_5...
# Procesing bwv108.6.mxl_chunk_6...
# Procesing bwv108.6.mxl_chunk_7...
# Procesing bwv108.6.mxl_chunk_8...
# Procesing bwv108.6.mxl_chunk_9...
# Procesing bwv11.6.mxl_chunk_0...
# Procesing bwv11.6.mxl_chunk_1...
# Procesing bwv11.6.mxl_chunk_10...
# Procesing bwv11.6.mxl_chunk_11...
# Procesing bwv11.6.mxl_chunk_12...
# Procesing bwv11.6.mxl_chunk_13...
# Procesing bwv11.6.mxl_chunk_14...
# Procesing bwv11.6.mxl_chunk_15...
# Procesing bwv11.6.mxl_chunk_16...
# Procesing bwv11.6.mxl_chunk_17...
# Procesing bwv11.6.mxl_chunk_18...
# Procesing bwv11.6.mxl_chunk_19...
# Procesing bwv11.6.mxl_chunk_2...
# Procesing bwv11.6.mxl_chunk_3...
# Procesing bwv11.6.mxl_chunk_4...
# Procesing bwv11.6.mxl_chunk_5...
# Procesing bwv11.6.mxl_chunk_6...
# Procesing bwv11.6.mxl_chunk_7...
# Procesing bwv11.6.mxl_chunk_8...
# Procesing bwv11.6.mxl_chunk_9...
# Procesing bwv110.7.mxl_chunk_0...
# Procesing bwv110.7.mxl_chunk_1...
# Procesing bwv110.7.mxl_chunk_2...
# Procesing bwv110.7.mxl_chunk_3...
# Procesing bwv110.7.mxl_chunk_4...
# Procesing bwv110.7.mxl_chunk_5...
# Procesing bwv110.7.mxl_chunk_6...
# Procesing bwv110.7.mxl_chunk_7...
# Procesing bwv111.6.mxl_chunk_0...
# Procesing bwv111.6.mxl_chunk_1...
# Procesing bwv111.6.mxl_chunk_10...
# Procesing bwv111.6.mxl_chunk_11...
# Procesing bwv111.6.mxl_chunk_12...
# Procesing bwv111.6.mxl_chunk_13...
# Procesing bwv111.6.mxl_chunk_14...
# Procesing bwv111.6.mxl_chunk_15...
# Procesing bwv111.6.mxl_chunk_16...
# Procesing bwv111.6.mxl_chunk_2...
# Procesing bwv111.6.mxl_chunk_3...
# Procesing bwv111.6.mxl_chunk_4...
# Procesing bwv111.6.mxl_chunk_5...
# Procesing bwv111.6.mxl_chunk_6...
# Procesing bwv111.6.mxl_chunk_7...
# Procesing bwv111.6.mxl_chunk_8...
# Procesing bwv111.6.mxl_chunk_9...
# Procesing bwv112.5.mxl_chunk_0...
# Procesing bwv112.5.mxl_chunk_1...
# Procesing bwv112.5.mxl_chunk_10...
# Procesing bwv112.5.mxl_chunk_2...
# Procesing bwv112.5.mxl_chunk_3...
# Procesing bwv112.5.mxl_chunk_4...
# Procesing bwv112.5.mxl_chunk_5...
# Procesing bwv112.5.mxl_chunk_6...
# Procesing bwv112.5.mxl_chunk_7...
# Procesing bwv112.5.mxl_chunk_8...
# Procesing bwv112.5.mxl_chunk_9...
# Procesing bwv113.8.mxl_chunk_0...
# Procesing bwv113.8.mxl_chunk_1...
# Procesing bwv113.8.mxl_chunk_2...
# Procesing bwv113.8.mxl_chunk_3...
# Procesing bwv113.8.mxl_chunk_4...
# Procesing bwv113.8.mxl_chunk_5...
# Procesing bwv113.8.mxl_chunk_6...
# Procesing bwv113.8.mxl_chunk_7...
# Procesing bwv113.8.mxl_chunk_8...
# Procesing bwv113.8.mxl_chunk_9...
# Procesing bwv114.7.mxl_chunk_0...
# Procesing bwv114.7.mxl_chunk_1...
# Procesing bwv114.7.mxl_chunk_2...
# Procesing bwv114.7.mxl_chunk_3...
# Procesing bwv114.7.mxl_chunk_4...
# Procesing bwv114.7.mxl_chunk_5...
# Procesing bwv114.7.mxl_chunk_6...
# Procesing bwv114.7.mxl_chunk_7...
# Procesing bwv115.6.mxl_chunk_0...
# Procesing bwv115.6.mxl_chunk_1...
# Procesing bwv115.6.mxl_chunk_2...
# Procesing bwv115.6.mxl_chunk_3...
# Procesing bwv115.6.mxl_chunk_4...
# Procesing bwv115.6.mxl_chunk_5...
# Procesing bwv115.6.mxl_chunk_6...
# Procesing bwv116.6.mxl_chunk_0...
# Procesing bwv116.6.mxl_chunk_1...
# Procesing bwv116.6.mxl_chunk_2...
# Procesing bwv116.6.mxl_chunk_3...
# Procesing bwv116.6.mxl_chunk_4...
# Procesing bwv116.6.mxl_chunk_5...
# Procesing bwv116.6.mxl_chunk_6...
# Procesing bwv116.6.mxl_chunk_7...
# Procesing bwv116.6.mxl_chunk_8...
# Procesing bwv116.6.mxl_chunk_9...
# Procesing bwv117.4.mxl_chunk_0...
# Procesing bwv117.4.mxl_chunk_1...
# Procesing bwv117.4.mxl_chunk_2...
# Procesing bwv117.4.mxl_chunk_3...
# Procesing bwv117.4.mxl_chunk_4...
# Procesing bwv117.4.mxl_chunk_5...
# Procesing bwv117.4.mxl_chunk_6...
# Procesing bwv117.4.mxl_chunk_7...
# Procesing bwv119.9.mxl_chunk_0...
# Procesing bwv119.9.mxl_chunk_1...
# Procesing bwv119.9.mxl_chunk_10...
# Procesing bwv119.9.mxl_chunk_11...
# Procesing bwv119.9.mxl_chunk_12...
# Procesing bwv119.9.mxl_chunk_13...
# Procesing bwv119.9.mxl_chunk_14...
# Procesing bwv119.9.mxl_chunk_15...
# Procesing bwv119.9.mxl_chunk_16...
# Procesing bwv119.9.mxl_chunk_2...
# Procesing bwv119.9.mxl_chunk_3...
# Procesing bwv119.9.mxl_chunk_4...
# Procesing bwv119.9.mxl_chunk_5...
# Procesing bwv119.9.mxl_chunk_6...
# Procesing bwv119.9.mxl_chunk_7...
# Procesing bwv119.9.mxl_chunk_8...
# Procesing bwv119.9.mxl_chunk_9...
# Procesing bwv120.6.mxl_chunk_0...
# Procesing bwv120.6.mxl_chunk_1...
# Procesing bwv120.6.mxl_chunk_10...
# Procesing bwv120.6.mxl_chunk_11...
# Procesing bwv120.6.mxl_chunk_12...
# Procesing bwv120.6.mxl_chunk_2...
# Procesing bwv120.6.mxl_chunk_3...
# Procesing bwv120.6.mxl_chunk_4...
# Procesing bwv120.6.mxl_chunk_5...
# Procesing bwv120.6.mxl_chunk_6...
# Procesing bwv120.6.mxl_chunk_7...
# Procesing bwv120.6.mxl_chunk_8...
# Procesing bwv120.6.mxl_chunk_9...
# Procesing bwv121.6.mxl_chunk_0...
# Procesing bwv121.6.mxl_chunk_1...
# Procesing bwv121.6.mxl_chunk_10...
# Procesing bwv121.6.mxl_chunk_11...
# Procesing bwv121.6.mxl_chunk_12...
# Procesing bwv121.6.mxl_chunk_13...
# Procesing bwv121.6.mxl_chunk_2...
# Procesing bwv121.6.mxl_chunk_3...
# Procesing bwv121.6.mxl_chunk_4...
# Procesing bwv121.6.mxl_chunk_5...
# Procesing bwv121.6.mxl_chunk_6...
# Procesing bwv121.6.mxl_chunk_7...
# Procesing bwv121.6.mxl_chunk_8...
# Procesing bwv121.6.mxl_chunk_9...
# Procesing bwv122.6.mxl_chunk_0...
# Procesing bwv122.6.mxl_chunk_1...
# Procesing bwv122.6.mxl_chunk_10...
# Procesing bwv122.6.mxl_chunk_11...
# Procesing bwv122.6.mxl_chunk_12...
# Procesing bwv122.6.mxl_chunk_2...
# Procesing bwv122.6.mxl_chunk_3...
# Procesing bwv122.6.mxl_chunk_4...
# Procesing bwv122.6.mxl_chunk_5...
# Procesing bwv122.6.mxl_chunk_6...
# Procesing bwv122.6.mxl_chunk_7...
# Procesing bwv122.6.mxl_chunk_8...
# Procesing bwv122.6.mxl_chunk_9...
# Procesing bwv123.6.mxl_chunk_0...
# Procesing bwv123.6.mxl_chunk_1...
# Procesing bwv123.6.mxl_chunk_10...
# Procesing bwv123.6.mxl_chunk_11...
# Procesing bwv123.6.mxl_chunk_12...
# Procesing bwv123.6.mxl_chunk_2...
# Procesing bwv123.6.mxl_chunk_3...
# Procesing bwv123.6.mxl_chunk_4...
# Procesing bwv123.6.mxl_chunk_5...
# Procesing bwv123.6.mxl_chunk_6...
# Procesing bwv123.6.mxl_chunk_7...
# Procesing bwv123.6.mxl_chunk_8...
# Procesing bwv123.6.mxl_chunk_9...
# Procesing bwv125.6.mxl_chunk_0...
# Procesing bwv125.6.mxl_chunk_1...
# Procesing bwv125.6.mxl_chunk_2...
# Procesing bwv125.6.mxl_chunk_3...
# Procesing bwv125.6.mxl_chunk_4...
# Procesing bwv125.6.mxl_chunk_5...
# Procesing bwv125.6.mxl_chunk_6...
# Procesing bwv125.6.mxl_chunk_7...
# Procesing bwv125.6.mxl_chunk_8...
# Procesing bwv126.6.mxl_chunk_0...
# Procesing bwv126.6.mxl_chunk_1...
# Procesing bwv126.6.mxl_chunk_10...
# Procesing bwv126.6.mxl_chunk_11...
# Procesing bwv126.6.mxl_chunk_12...
# Procesing bwv126.6.mxl_chunk_13...
# Procesing bwv126.6.mxl_chunk_14...
# Procesing bwv126.6.mxl_chunk_15...
# Procesing bwv126.6.mxl_chunk_16...
# Procesing bwv126.6.mxl_chunk_17...
# Procesing bwv126.6.mxl_chunk_18...
# Procesing bwv126.6.mxl_chunk_19...
# Procesing bwv126.6.mxl_chunk_2...
# Procesing bwv126.6.mxl_chunk_20...
# Procesing bwv126.6.mxl_chunk_21...
# Procesing bwv126.6.mxl_chunk_22...
# Procesing bwv126.6.mxl_chunk_23...
# Procesing bwv126.6.mxl_chunk_24...
# Procesing bwv126.6.mxl_chunk_25...
# Procesing bwv126.6.mxl_chunk_3...
# Procesing bwv126.6.mxl_chunk_4...
# Procesing bwv126.6.mxl_chunk_5...
# Procesing bwv126.6.mxl_chunk_6...
# Procesing bwv126.6.mxl_chunk_7...
# Procesing bwv126.6.mxl_chunk_8...
# Procesing bwv126.6.mxl_chunk_9...
# Procesing bwv127.5.mxl_chunk_0...
# Procesing bwv127.5.mxl_chunk_1...
# Procesing bwv127.5.mxl_chunk_10...
# Procesing bwv127.5.mxl_chunk_2...
# Procesing bwv127.5.mxl_chunk_3...
# Procesing bwv127.5.mxl_chunk_4...
# Procesing bwv127.5.mxl_chunk_5...
# Procesing bwv127.5.mxl_chunk_6...
# Procesing bwv127.5.mxl_chunk_7...
# Procesing bwv127.5.mxl_chunk_8...
# Procesing bwv127.5.mxl_chunk_9...
# Procesing bwv13.6.mxl_chunk_0...
# Procesing bwv13.6.mxl_chunk_1...
# Procesing bwv13.6.mxl_chunk_10...
# Procesing bwv13.6.mxl_chunk_2...
# Procesing bwv13.6.mxl_chunk_3...
# Procesing bwv13.6.mxl_chunk_4...
# Procesing bwv13.6.mxl_chunk_5...
# Procesing bwv13.6.mxl_chunk_6...
# Procesing bwv13.6.mxl_chunk_7...
# Procesing bwv13.6.mxl_chunk_8...
# Procesing bwv13.6.mxl_chunk_9...
# Procesing bwv133.6.mxl_chunk_0...
# Procesing bwv133.6.mxl_chunk_1...
# Procesing bwv133.6.mxl_chunk_10...
# Procesing bwv133.6.mxl_chunk_2...
# Procesing bwv133.6.mxl_chunk_3...
# Procesing bwv133.6.mxl_chunk_4...
# Procesing bwv133.6.mxl_chunk_5...
# Procesing bwv133.6.mxl_chunk_6...
# Procesing bwv133.6.mxl_chunk_7...
# Procesing bwv133.6.mxl_chunk_8...
# Procesing bwv133.6.mxl_chunk_9...
# Procesing bwv135.6.mxl_chunk_0...
# Procesing bwv135.6.mxl_chunk_1...
# Procesing bwv135.6.mxl_chunk_10...
# Procesing bwv135.6.mxl_chunk_11...
# Procesing bwv135.6.mxl_chunk_12...
# Procesing bwv135.6.mxl_chunk_2...
# Procesing bwv135.6.mxl_chunk_3...
# Procesing bwv135.6.mxl_chunk_4...
# Procesing bwv135.6.mxl_chunk_5...
# Procesing bwv135.6.mxl_chunk_6...
# Procesing bwv135.6.mxl_chunk_7...
# Procesing bwv135.6.mxl_chunk_8...
# Procesing bwv135.6.mxl_chunk_9...
# Procesing bwv139.6.mxl_chunk_0...
# Procesing bwv139.6.mxl_chunk_1...
# Procesing bwv139.6.mxl_chunk_2...
# Procesing bwv139.6.mxl_chunk_3...
# Procesing bwv139.6.mxl_chunk_4...
# Procesing bwv139.6.mxl_chunk_5...
# Procesing bwv139.6.mxl_chunk_6...
# Procesing bwv139.6.mxl_chunk_7...
# Procesing bwv139.6.mxl_chunk_8...
# Procesing bwv14.5.mxl_chunk_0...
# Procesing bwv14.5.mxl_chunk_1...
# Procesing bwv14.5.mxl_chunk_2...
# Procesing bwv14.5.mxl_chunk_3...
# Procesing bwv14.5.mxl_chunk_4...
# Procesing bwv14.5.mxl_chunk_5...
# Procesing bwv14.5.mxl_chunk_6...
# Procesing bwv14.5.mxl_chunk_7...
# Procesing bwv140.7.mxl_chunk_0...
# Procesing bwv140.7.mxl_chunk_1...
# Procesing bwv140.7.mxl_chunk_10...
# Procesing bwv140.7.mxl_chunk_11...
# Procesing bwv140.7.mxl_chunk_12...
# Procesing bwv140.7.mxl_chunk_13...
# Procesing bwv140.7.mxl_chunk_14...
# Procesing bwv140.7.mxl_chunk_2...
# Procesing bwv140.7.mxl_chunk_3...
# Procesing bwv140.7.mxl_chunk_4...
# Procesing bwv140.7.mxl_chunk_5...
# Procesing bwv140.7.mxl_chunk_6...
# Procesing bwv140.7.mxl_chunk_7...
# Procesing bwv140.7.mxl_chunk_8...
# Procesing bwv140.7.mxl_chunk_9...
# Procesing bwv144.3.mxl_chunk_0...
# Procesing bwv144.3.mxl_chunk_1...
# Procesing bwv144.3.mxl_chunk_2...
# Procesing bwv144.3.mxl_chunk_3...
# Procesing bwv144.3.mxl_chunk_4...
# Procesing bwv144.3.mxl_chunk_5...
# Procesing bwv144.3.mxl_chunk_6...
# Procesing bwv144.3.mxl_chunk_7...
# Procesing bwv144.6.mxl_chunk_0...
# Procesing bwv144.6.mxl_chunk_1...
# Procesing bwv144.6.mxl_chunk_10...
# Procesing bwv144.6.mxl_chunk_11...
# Procesing bwv144.6.mxl_chunk_12...
# Procesing bwv144.6.mxl_chunk_13...
# Procesing bwv144.6.mxl_chunk_2...
# Procesing bwv144.6.mxl_chunk_3...
# Procesing bwv144.6.mxl_chunk_4...
# Procesing bwv144.6.mxl_chunk_5...
# Procesing bwv144.6.mxl_chunk_6...
# Procesing bwv144.6.mxl_chunk_7...
# Procesing bwv144.6.mxl_chunk_8...
# Procesing bwv144.6.mxl_chunk_9...
# Procesing bwv145-a.mxl_chunk_0...
# Procesing bwv145-a.mxl_chunk_1...
# Procesing bwv145-a.mxl_chunk_2...
# Procesing bwv145-a.mxl_chunk_3...
# Procesing bwv145-a.mxl_chunk_4...
# Procesing bwv145-a.mxl_chunk_5...
# Procesing bwv145-a.mxl_chunk_6...
# Procesing bwv145-a.mxl_chunk_7...
# Procesing bwv145-a.mxl_chunk_8...
# Procesing bwv145.5.mxl_chunk_0...
# Procesing bwv145.5.mxl_chunk_1...
# Procesing bwv145.5.mxl_chunk_10...
# Procesing bwv145.5.mxl_chunk_11...
# Procesing bwv145.5.mxl_chunk_12...
# Procesing bwv145.5.mxl_chunk_13...
# Procesing bwv145.5.mxl_chunk_14...
# Procesing bwv145.5.mxl_chunk_15...
# Procesing bwv145.5.mxl_chunk_2...
# Procesing bwv145.5.mxl_chunk_3...
# Procesing bwv145.5.mxl_chunk_4...
# Procesing bwv145.5.mxl_chunk_5...
# Procesing bwv145.5.mxl_chunk_6...
# Procesing bwv145.5.mxl_chunk_7...
# Procesing bwv145.5.mxl_chunk_8...
# Procesing bwv145.5.mxl_chunk_9...
# Procesing bwv146.8.mxl_chunk_0...
# Procesing bwv146.8.mxl_chunk_1...
# Procesing bwv146.8.mxl_chunk_10...
# Procesing bwv146.8.mxl_chunk_11...
# Procesing bwv146.8.mxl_chunk_12...
# Procesing bwv146.8.mxl_chunk_2...
# Procesing bwv146.8.mxl_chunk_3...
# Procesing bwv146.8.mxl_chunk_4...
# Procesing bwv146.8.mxl_chunk_5...
# Procesing bwv146.8.mxl_chunk_6...
# Procesing bwv146.8.mxl_chunk_7...
# Procesing bwv146.8.mxl_chunk_8...
# Procesing bwv146.8.mxl_chunk_9...
# Procesing bwv148.6.mxl_chunk_0...
# Procesing bwv148.6.mxl_chunk_1...
# Procesing bwv148.6.mxl_chunk_10...
# Procesing bwv148.6.mxl_chunk_2...
# Procesing bwv148.6.mxl_chunk_3...
# Procesing bwv148.6.mxl_chunk_4...
# Procesing bwv148.6.mxl_chunk_5...
# Procesing bwv148.6.mxl_chunk_6...
# Procesing bwv148.6.mxl_chunk_7...
# Procesing bwv148.6.mxl_chunk_8...
# Procesing bwv148.6.mxl_chunk_9...
# Procesing bwv151.5.mxl_chunk_0...
# Procesing bwv151.5.mxl_chunk_1...
# Procesing bwv151.5.mxl_chunk_2...
# Procesing bwv151.5.mxl_chunk_3...
# Procesing bwv151.5.mxl_chunk_4...
# Procesing bwv151.5.mxl_chunk_5...
# Procesing bwv151.5.mxl_chunk_6...
# Procesing bwv151.5.mxl_chunk_7...
# Procesing bwv153.1.mxl_chunk_0...
# Procesing bwv153.1.mxl_chunk_1...
# Procesing bwv153.1.mxl_chunk_2...
# Procesing bwv153.1.mxl_chunk_3...
# Procesing bwv153.1.mxl_chunk_4...
# Procesing bwv153.1.mxl_chunk_5...
# Procesing bwv153.1.mxl_chunk_6...
# Procesing bwv153.1.mxl_chunk_7...
# Procesing bwv153.5.mxl_chunk_0...
# Procesing bwv153.5.mxl_chunk_1...
# Procesing bwv153.5.mxl_chunk_10...
# Procesing bwv153.5.mxl_chunk_2...
# Procesing bwv153.5.mxl_chunk_3...
# Procesing bwv153.5.mxl_chunk_4...
# Procesing bwv153.5.mxl_chunk_5...
# Procesing bwv153.5.mxl_chunk_6...
# Procesing bwv153.5.mxl_chunk_7...
# Procesing bwv153.5.mxl_chunk_8...
# Procesing bwv153.5.mxl_chunk_9...
# Procesing bwv153.9.mxl_chunk_0...
# Procesing bwv153.9.mxl_chunk_1...
# Procesing bwv153.9.mxl_chunk_10...
# Procesing bwv153.9.mxl_chunk_11...
# Procesing bwv153.9.mxl_chunk_12...
# Procesing bwv153.9.mxl_chunk_2...
# Procesing bwv153.9.mxl_chunk_3...
# Procesing bwv153.9.mxl_chunk_4...
# Procesing bwv153.9.mxl_chunk_5...
# Procesing bwv153.9.mxl_chunk_6...
# Procesing bwv153.9.mxl_chunk_7...
# Procesing bwv153.9.mxl_chunk_8...
# Procesing bwv153.9.mxl_chunk_9...
# Procesing bwv154.3.mxl_chunk_0...
# Procesing bwv154.3.mxl_chunk_1...
# Procesing bwv154.3.mxl_chunk_2...
# Procesing bwv154.3.mxl_chunk_3...
# Procesing bwv154.3.mxl_chunk_4...
# Procesing bwv154.3.mxl_chunk_5...
# Procesing bwv154.3.mxl_chunk_6...
# Procesing bwv154.3.mxl_chunk_7...
# Procesing bwv154.3.mxl_chunk_8...
# Procesing bwv154.8.mxl_chunk_0...
# Procesing bwv154.8.mxl_chunk_1...
# Procesing bwv154.8.mxl_chunk_10...
# Procesing bwv154.8.mxl_chunk_2...
# Procesing bwv154.8.mxl_chunk_3...
# Procesing bwv154.8.mxl_chunk_4...
# Procesing bwv154.8.mxl_chunk_5...
# Procesing bwv154.8.mxl_chunk_6...
# Procesing bwv154.8.mxl_chunk_7...
# Procesing bwv154.8.mxl_chunk_8...
# Procesing bwv154.8.mxl_chunk_9...
# Procesing bwv155.5.mxl_chunk_0...
# Procesing bwv155.5.mxl_chunk_1...
# Procesing bwv155.5.mxl_chunk_2...
# Procesing bwv155.5.mxl_chunk_3...
# Procesing bwv155.5.mxl_chunk_4...
# Procesing bwv155.5.mxl_chunk_5...
# Procesing bwv155.5.mxl_chunk_6...
# Procesing bwv155.5.mxl_chunk_7...
# Procesing bwv156.6.mxl_chunk_0...
# Procesing bwv156.6.mxl_chunk_1...
# Procesing bwv156.6.mxl_chunk_2...
# Procesing bwv156.6.mxl_chunk_3...
# Procesing bwv156.6.mxl_chunk_4...
# Procesing bwv156.6.mxl_chunk_5...
# Procesing bwv156.6.mxl_chunk_6...
# Procesing bwv156.6.mxl_chunk_7...
# Procesing bwv156.6.mxl_chunk_8...
# Procesing bwv156.6.mxl_chunk_9...
# Procesing bwv157.5.mxl_chunk_0...
# Procesing bwv157.5.mxl_chunk_1...
# Procesing bwv157.5.mxl_chunk_2...
# Procesing bwv157.5.mxl_chunk_3...
# Procesing bwv157.5.mxl_chunk_4...
# Procesing bwv157.5.mxl_chunk_5...
# Procesing bwv157.5.mxl_chunk_6...
# Procesing bwv157.5.mxl_chunk_7...
# Procesing bwv157.5.mxl_chunk_8...
# Procesing bwv157.5.mxl_chunk_9...
# Procesing bwv158.4.mxl_chunk_0...
# Procesing bwv158.4.mxl_chunk_1...
# Procesing bwv158.4.mxl_chunk_10...
# Procesing bwv158.4.mxl_chunk_11...
# Procesing bwv158.4.mxl_chunk_12...
# Procesing bwv158.4.mxl_chunk_2...
# Procesing bwv158.4.mxl_chunk_3...
# Procesing bwv158.4.mxl_chunk_4...
# Procesing bwv158.4.mxl_chunk_5...
# Procesing bwv158.4.mxl_chunk_6...
# Procesing bwv158.4.mxl_chunk_7...
# Procesing bwv158.4.mxl_chunk_8...
# Procesing bwv158.4.mxl_chunk_9...
# Procesing bwv159.5.mxl_chunk_0...
# Procesing bwv159.5.mxl_chunk_1...
# Procesing bwv159.5.mxl_chunk_10...
# Procesing bwv159.5.mxl_chunk_11...
# Procesing bwv159.5.mxl_chunk_12...
# Procesing bwv159.5.mxl_chunk_2...
# Procesing bwv159.5.mxl_chunk_3...
# Procesing bwv159.5.mxl_chunk_4...
# Procesing bwv159.5.mxl_chunk_5...
# Procesing bwv159.5.mxl_chunk_6...
# Procesing bwv159.5.mxl_chunk_7...
# Procesing bwv159.5.mxl_chunk_8...
# Procesing bwv159.5.mxl_chunk_9...
# Procesing bwv16.6.mxl_chunk_0...
# Procesing bwv16.6.mxl_chunk_1...
# Procesing bwv16.6.mxl_chunk_10...
# Procesing bwv16.6.mxl_chunk_2...
# Procesing bwv16.6.mxl_chunk_3...
# Procesing bwv16.6.mxl_chunk_4...
# Procesing bwv16.6.mxl_chunk_5...
# Procesing bwv16.6.mxl_chunk_6...
# Procesing bwv16.6.mxl_chunk_7...
# Procesing bwv16.6.mxl_chunk_8...
# Procesing bwv16.6.mxl_chunk_9...
# Procesing bwv162.6-lpz.mxl_chunk_0...
# Procesing bwv162.6-lpz.mxl_chunk_1...
# Procesing bwv162.6-lpz.mxl_chunk_10...
# Procesing bwv162.6-lpz.mxl_chunk_11...
# Procesing bwv162.6-lpz.mxl_chunk_12...
# Procesing bwv162.6-lpz.mxl_chunk_2...
# Procesing bwv162.6-lpz.mxl_chunk_3...
# Procesing bwv162.6-lpz.mxl_chunk_4...
# Procesing bwv162.6-lpz.mxl_chunk_5...
# Procesing bwv162.6-lpz.mxl_chunk_6...
# Procesing bwv162.6-lpz.mxl_chunk_7...
# Procesing bwv162.6-lpz.mxl_chunk_8...
# Procesing bwv162.6-lpz.mxl_chunk_9...
# Procesing bwv164.6.mxl_chunk_0...
# Procesing bwv164.6.mxl_chunk_1...
# Procesing bwv164.6.mxl_chunk_2...
# Procesing bwv164.6.mxl_chunk_3...
# Procesing bwv164.6.mxl_chunk_4...
# Procesing bwv164.6.mxl_chunk_5...
# Procesing bwv164.6.mxl_chunk_6...
# Procesing bwv164.6.mxl_chunk_7...
# Procesing bwv165.6.mxl_chunk_0...
# Procesing bwv165.6.mxl_chunk_1...
# Procesing bwv165.6.mxl_chunk_2...
# Procesing bwv165.6.mxl_chunk_3...
# Procesing bwv165.6.mxl_chunk_4...
# Procesing bwv166.6.mxl_chunk_0...
# Procesing bwv166.6.mxl_chunk_1...
# Procesing bwv166.6.mxl_chunk_2...
# Procesing bwv166.6.mxl_chunk_3...
# Procesing bwv166.6.mxl_chunk_4...
# Procesing bwv166.6.mxl_chunk_5...
# Procesing bwv166.6.mxl_chunk_6...
# Procesing bwv168.6.mxl_chunk_0...
# Procesing bwv168.6.mxl_chunk_1...
# Procesing bwv168.6.mxl_chunk_2...
# Procesing bwv168.6.mxl_chunk_3...
# Procesing bwv168.6.mxl_chunk_4...
# Procesing bwv168.6.mxl_chunk_5...
# Procesing bwv168.6.mxl_chunk_6...
# Procesing bwv168.6.mxl_chunk_7...
# Procesing bwv168.6.mxl_chunk_8...
# Procesing bwv168.6.mxl_chunk_9...
# Procesing bwv169.7.mxl_chunk_0...
# Procesing bwv169.7.mxl_chunk_1...
# Procesing bwv169.7.mxl_chunk_10...
# Procesing bwv169.7.mxl_chunk_11...
# Procesing bwv169.7.mxl_chunk_2...
# Procesing bwv169.7.mxl_chunk_3...
# Procesing bwv169.7.mxl_chunk_4...
# Procesing bwv169.7.mxl_chunk_5...
# Procesing bwv169.7.mxl_chunk_6...
# Procesing bwv169.7.mxl_chunk_7...
# Procesing bwv169.7.mxl_chunk_8...
# Procesing bwv169.7.mxl_chunk_9...
# Procesing bwv17.7.mxl_chunk_0...
# Procesing bwv17.7.mxl_chunk_1...
# Procesing bwv17.7.mxl_chunk_10...
# Procesing bwv17.7.mxl_chunk_11...
# Procesing bwv17.7.mxl_chunk_12...
# Procesing bwv17.7.mxl_chunk_13...
# Procesing bwv17.7.mxl_chunk_14...
# Procesing bwv17.7.mxl_chunk_15...
# Procesing bwv17.7.mxl_chunk_16...
# Procesing bwv17.7.mxl_chunk_17...
# Procesing bwv17.7.mxl_chunk_18...
# Procesing bwv17.7.mxl_chunk_19...
# Procesing bwv17.7.mxl_chunk_2...
# Procesing bwv17.7.mxl_chunk_20...
# Procesing bwv17.7.mxl_chunk_21...
# Procesing bwv17.7.mxl_chunk_22...
# Procesing bwv17.7.mxl_chunk_23...
# Procesing bwv17.7.mxl_chunk_24...
# Procesing bwv17.7.mxl_chunk_25...
# Procesing bwv17.7.mxl_chunk_26...
# Procesing bwv17.7.mxl_chunk_27...
# Procesing bwv17.7.mxl_chunk_28...
# Procesing bwv17.7.mxl_chunk_29...
# Procesing bwv17.7.mxl_chunk_3...
# Procesing bwv17.7.mxl_chunk_30...
# Procesing bwv17.7.mxl_chunk_31...
# Procesing bwv17.7.mxl_chunk_32...
# Procesing bwv17.7.mxl_chunk_33...
# Procesing bwv17.7.mxl_chunk_34...
# Procesing bwv17.7.mxl_chunk_35...
# Procesing bwv17.7.mxl_chunk_36...
# Procesing bwv17.7.mxl_chunk_37...
# Procesing bwv17.7.mxl_chunk_4...
# Procesing bwv17.7.mxl_chunk_5...
# Procesing bwv17.7.mxl_chunk_6...
# Procesing bwv17.7.mxl_chunk_7...
# Procesing bwv17.7.mxl_chunk_8...
# Procesing bwv17.7.mxl_chunk_9...
# Procesing bwv174.5.mxl_chunk_0...
# Procesing bwv174.5.mxl_chunk_1...
# Procesing bwv174.5.mxl_chunk_10...
# Procesing bwv174.5.mxl_chunk_11...
# Procesing bwv174.5.mxl_chunk_12...
# Procesing bwv174.5.mxl_chunk_13...
# Procesing bwv174.5.mxl_chunk_14...
# Procesing bwv174.5.mxl_chunk_15...
# Procesing bwv174.5.mxl_chunk_16...
# Procesing bwv174.5.mxl_chunk_2...
# Procesing bwv174.5.mxl_chunk_3...
# Procesing bwv174.5.mxl_chunk_4...
# Procesing bwv174.5.mxl_chunk_5...
# Procesing bwv174.5.mxl_chunk_6...
# Procesing bwv174.5.mxl_chunk_7...
# Procesing bwv174.5.mxl_chunk_8...
# Procesing bwv174.5.mxl_chunk_9...
# Procesing bwv176.6.mxl_chunk_0...
# Procesing bwv176.6.mxl_chunk_1...
# Procesing bwv176.6.mxl_chunk_10...
# Procesing bwv176.6.mxl_chunk_11...
# Procesing bwv176.6.mxl_chunk_12...
# Procesing bwv176.6.mxl_chunk_13...
# Procesing bwv176.6.mxl_chunk_14...
# Procesing bwv176.6.mxl_chunk_15...
# Procesing bwv176.6.mxl_chunk_16...
# Procesing bwv176.6.mxl_chunk_17...
# Procesing bwv176.6.mxl_chunk_18...
# Procesing bwv176.6.mxl_chunk_2...
# Procesing bwv176.6.mxl_chunk_3...
# Procesing bwv176.6.mxl_chunk_4...
# Procesing bwv176.6.mxl_chunk_5...
# Procesing bwv176.6.mxl_chunk_6...
# Procesing bwv176.6.mxl_chunk_7...
# Procesing bwv176.6.mxl_chunk_8...
# Procesing bwv176.6.mxl_chunk_9...
# Procesing bwv177.4.mxl_chunk_0...
# Procesing bwv177.4.mxl_chunk_1...
# Procesing bwv177.4.mxl_chunk_2...
# Procesing bwv177.4.mxl_chunk_3...
# Procesing bwv177.4.mxl_chunk_4...
# Procesing bwv177.4.mxl_chunk_5...
# Procesing bwv177.4.mxl_chunk_6...
# Procesing bwv177.4.mxl_chunk_7...
# Procesing bwv177.5.mxl_chunk_0...
# Procesing bwv177.5.mxl_chunk_1...
# Procesing bwv177.5.mxl_chunk_10...
# Procesing bwv177.5.mxl_chunk_2...
# Procesing bwv177.5.mxl_chunk_3...
# Procesing bwv177.5.mxl_chunk_4...
# Procesing bwv177.5.mxl_chunk_5...
# Procesing bwv177.5.mxl_chunk_6...
# Procesing bwv177.5.mxl_chunk_7...
# Procesing bwv177.5.mxl_chunk_8...
# Procesing bwv177.5.mxl_chunk_9...
# Procesing bwv178.7.mxl_chunk_0...
# Procesing bwv178.7.mxl_chunk_1...
# Procesing bwv178.7.mxl_chunk_10...
# Procesing bwv178.7.mxl_chunk_2...
# Procesing bwv178.7.mxl_chunk_3...
# Procesing bwv178.7.mxl_chunk_4...
# Procesing bwv178.7.mxl_chunk_5...
# Procesing bwv178.7.mxl_chunk_6...
# Procesing bwv178.7.mxl_chunk_7...
# Procesing bwv178.7.mxl_chunk_8...
# Procesing bwv178.7.mxl_chunk_9...
# Procesing bwv179.6.mxl_chunk_0...
# Procesing bwv179.6.mxl_chunk_1...
# Procesing bwv179.6.mxl_chunk_2...
# Procesing bwv179.6.mxl_chunk_3...
# Procesing bwv179.6.mxl_chunk_4...
# Procesing bwv179.6.mxl_chunk_5...
# Procesing bwv179.6.mxl_chunk_6...
# Procesing bwv18.5-lz.mxl_chunk_0...
# Procesing bwv18.5-lz.mxl_chunk_1...
# Procesing bwv18.5-lz.mxl_chunk_10...
# Procesing bwv18.5-lz.mxl_chunk_11...
# Procesing bwv18.5-lz.mxl_chunk_2...
# Procesing bwv18.5-lz.mxl_chunk_3...
# Procesing bwv18.5-lz.mxl_chunk_4...
# Procesing bwv18.5-lz.mxl_chunk_5...
# Procesing bwv18.5-lz.mxl_chunk_6...
# Procesing bwv18.5-lz.mxl_chunk_7...
# Procesing bwv18.5-lz.mxl_chunk_8...
# Procesing bwv18.5-lz.mxl_chunk_9...
# Procesing bwv18.5-w.mxl_chunk_0...
# Procesing bwv18.5-w.mxl_chunk_1...
# Procesing bwv18.5-w.mxl_chunk_10...
# Procesing bwv18.5-w.mxl_chunk_11...
# Procesing bwv18.5-w.mxl_chunk_2...
# Procesing bwv18.5-w.mxl_chunk_3...
# Procesing bwv18.5-w.mxl_chunk_4...
# Procesing bwv18.5-w.mxl_chunk_5...
# Procesing bwv18.5-w.mxl_chunk_6...
# Procesing bwv18.5-w.mxl_chunk_7...
# Procesing bwv18.5-w.mxl_chunk_8...
# Procesing bwv18.5-w.mxl_chunk_9...
# Procesing bwv180.7.mxl_chunk_0...
# Procesing bwv180.7.mxl_chunk_1...
# Procesing bwv180.7.mxl_chunk_10...
# Procesing bwv180.7.mxl_chunk_11...
# Procesing bwv180.7.mxl_chunk_2...
# Procesing bwv180.7.mxl_chunk_3...
# Procesing bwv180.7.mxl_chunk_4...
# Procesing bwv180.7.mxl_chunk_5...
# Procesing bwv180.7.mxl_chunk_6...
# Procesing bwv180.7.mxl_chunk_7...
# Procesing bwv180.7.mxl_chunk_8...
# Procesing bwv180.7.mxl_chunk_9...
# Procesing bwv183.5.mxl_chunk_0...
# Procesing bwv183.5.mxl_chunk_1...
# Procesing bwv183.5.mxl_chunk_10...
# Procesing bwv183.5.mxl_chunk_2...
# Procesing bwv183.5.mxl_chunk_3...
# Procesing bwv183.5.mxl_chunk_4...
# Procesing bwv183.5.mxl_chunk_5...
# Procesing bwv183.5.mxl_chunk_6...
# Procesing bwv183.5.mxl_chunk_7...
# Procesing bwv183.5.mxl_chunk_8...
# Procesing bwv183.5.mxl_chunk_9...
# Procesing bwv184.5.mxl_chunk_0...
# Procesing bwv184.5.mxl_chunk_1...
# Procesing bwv184.5.mxl_chunk_10...
# Procesing bwv184.5.mxl_chunk_11...
# Procesing bwv184.5.mxl_chunk_12...
# Procesing bwv184.5.mxl_chunk_2...
# Procesing bwv184.5.mxl_chunk_3...
# Procesing bwv184.5.mxl_chunk_4...
# Procesing bwv184.5.mxl_chunk_5...
# Procesing bwv184.5.mxl_chunk_6...
# Procesing bwv184.5.mxl_chunk_7...
# Procesing bwv184.5.mxl_chunk_8...
# Procesing bwv184.5.mxl_chunk_9...
# Procesing bwv187.7.mxl_chunk_0...
# Procesing bwv187.7.mxl_chunk_1...
# Procesing bwv187.7.mxl_chunk_10...
# Procesing bwv187.7.mxl_chunk_11...
# Procesing bwv187.7.mxl_chunk_12...
# Procesing bwv187.7.mxl_chunk_13...
# Procesing bwv187.7.mxl_chunk_14...
# Procesing bwv187.7.mxl_chunk_15...
# Procesing bwv187.7.mxl_chunk_16...
# Procesing bwv187.7.mxl_chunk_17...
# Procesing bwv187.7.mxl_chunk_18...
# Procesing bwv187.7.mxl_chunk_19...
# Procesing bwv187.7.mxl_chunk_2...
# Procesing bwv187.7.mxl_chunk_20...
# Procesing bwv187.7.mxl_chunk_21...
# Procesing bwv187.7.mxl_chunk_22...
# Procesing bwv187.7.mxl_chunk_23...
# Procesing bwv187.7.mxl_chunk_24...
# Procesing bwv187.7.mxl_chunk_3...
# Procesing bwv187.7.mxl_chunk_4...
# Procesing bwv187.7.mxl_chunk_5...
# Procesing bwv187.7.mxl_chunk_6...
# Procesing bwv187.7.mxl_chunk_7...
# Procesing bwv187.7.mxl_chunk_8...
# Procesing bwv187.7.mxl_chunk_9...
# Procesing bwv188.6.mxl_chunk_0...
# Procesing bwv188.6.mxl_chunk_1...
# Procesing bwv188.6.mxl_chunk_2...
# Procesing bwv188.6.mxl_chunk_3...
# Procesing bwv188.6.mxl_chunk_4...
# Procesing bwv188.6.mxl_chunk_5...
# Procesing bwv188.6.mxl_chunk_6...
# Procesing bwv188.6.mxl_chunk_7...
# Procesing bwv188.6.mxl_chunk_8...
# Procesing bwv190.7.mxl_chunk_0...
# Procesing bwv190.7.mxl_chunk_1...
# Procesing bwv190.7.mxl_chunk_10...
# Procesing bwv190.7.mxl_chunk_11...
# Procesing bwv190.7.mxl_chunk_12...
# Procesing bwv190.7.mxl_chunk_13...
# Procesing bwv190.7.mxl_chunk_14...
# Procesing bwv190.7.mxl_chunk_15...
# Procesing bwv190.7.mxl_chunk_16...
# Procesing bwv190.7.mxl_chunk_17...
# Procesing bwv190.7.mxl_chunk_18...
# Procesing bwv190.7.mxl_chunk_19...
# Procesing bwv190.7.mxl_chunk_2...
# Procesing bwv190.7.mxl_chunk_20...
# Procesing bwv190.7.mxl_chunk_21...
# Procesing bwv190.7.mxl_chunk_22...
# Procesing bwv190.7.mxl_chunk_23...
# Procesing bwv190.7.mxl_chunk_24...
# Procesing bwv190.7.mxl_chunk_25...
# Procesing bwv190.7.mxl_chunk_26...
# Procesing bwv190.7.mxl_chunk_27...
# Procesing bwv190.7.mxl_chunk_28...
# Procesing bwv190.7.mxl_chunk_3...
# Procesing bwv190.7.mxl_chunk_4...
# Procesing bwv190.7.mxl_chunk_5...
# Procesing bwv190.7.mxl_chunk_6...
# Procesing bwv190.7.mxl_chunk_7...
# Procesing bwv190.7.mxl_chunk_8...
# Procesing bwv190.7.mxl_chunk_9...
# Procesing bwv194.12.mxl_chunk_0...
# Procesing bwv194.12.mxl_chunk_1...
# Procesing bwv194.12.mxl_chunk_10...
# Procesing bwv194.12.mxl_chunk_11...
# Procesing bwv194.12.mxl_chunk_12...
# Procesing bwv194.12.mxl_chunk_13...
# Procesing bwv194.12.mxl_chunk_2...
# Procesing bwv194.12.mxl_chunk_3...
# Procesing bwv194.12.mxl_chunk_4...
# Procesing bwv194.12.mxl_chunk_5...
# Procesing bwv194.12.mxl_chunk_6...
# Procesing bwv194.12.mxl_chunk_7...
# Procesing bwv194.12.mxl_chunk_8...
# Procesing bwv194.12.mxl_chunk_9...
# Procesing bwv194.6.mxl_chunk_0...
# Procesing bwv194.6.mxl_chunk_1...
# Procesing bwv194.6.mxl_chunk_2...
# Procesing bwv194.6.mxl_chunk_3...
# Procesing bwv194.6.mxl_chunk_4...
# Procesing bwv194.6.mxl_chunk_5...
# Procesing bwv194.6.mxl_chunk_6...
# Procesing bwv194.6.mxl_chunk_7...
# Procesing bwv194.6.mxl_chunk_8...
# Procesing bwv194.6.mxl_chunk_9...
# Procesing bwv197.10.mxl_chunk_0...
# Procesing bwv197.10.mxl_chunk_1...
# Procesing bwv197.10.mxl_chunk_2...
# Procesing bwv197.10.mxl_chunk_3...
# Procesing bwv197.10.mxl_chunk_4...
# Procesing bwv197.10.mxl_chunk_5...
# Procesing bwv197.10.mxl_chunk_6...
# Procesing bwv197.5.mxl_chunk_0...
# Procesing bwv197.5.mxl_chunk_1...
# Procesing bwv197.5.mxl_chunk_10...
# Procesing bwv197.5.mxl_chunk_2...
# Procesing bwv197.5.mxl_chunk_3...
# Procesing bwv197.5.mxl_chunk_4...
# Procesing bwv197.5.mxl_chunk_5...
# Procesing bwv197.5.mxl_chunk_6...
# Procesing bwv197.5.mxl_chunk_7...
# Procesing bwv197.5.mxl_chunk_8...
# Procesing bwv197.5.mxl_chunk_9...
# Procesing bwv197.7-a.mxl_chunk_0...
# Procesing bwv197.7-a.mxl_chunk_1...
# Procesing bwv197.7-a.mxl_chunk_10...
# Procesing bwv197.7-a.mxl_chunk_11...
# Procesing bwv197.7-a.mxl_chunk_12...
# Procesing bwv197.7-a.mxl_chunk_2...
# Procesing bwv197.7-a.mxl_chunk_3...
# Procesing bwv197.7-a.mxl_chunk_4...
# Procesing bwv197.7-a.mxl_chunk_5...
# Procesing bwv197.7-a.mxl_chunk_6...
# Procesing bwv197.7-a.mxl_chunk_7...
# Procesing bwv197.7-a.mxl_chunk_8...
# Procesing bwv197.7-a.mxl_chunk_9...
# Procesing bwv2.6.mxl_chunk_0...
# Procesing bwv2.6.mxl_chunk_1...
# Procesing bwv2.6.mxl_chunk_2...
# Procesing bwv2.6.mxl_chunk_3...
# Procesing bwv2.6.mxl_chunk_4...
# Procesing bwv2.6.mxl_chunk_5...
# Procesing bwv2.6.mxl_chunk_6...
# Procesing bwv2.6.mxl_chunk_7...
# Procesing bwv2.6.mxl_chunk_8...
# Procesing bwv20.11.mxl_chunk_0...
# Procesing bwv20.11.mxl_chunk_1...
# Procesing bwv20.11.mxl_chunk_2...
# Procesing bwv20.11.mxl_chunk_3...
# Procesing bwv20.11.mxl_chunk_4...
# Procesing bwv20.11.mxl_chunk_5...
# Procesing bwv20.11.mxl_chunk_6...
# Procesing bwv20.11.mxl_chunk_7...
# Procesing bwv20.7.mxl_chunk_0...
# Procesing bwv20.7.mxl_chunk_1...
# Procesing bwv20.7.mxl_chunk_10...
# Procesing bwv20.7.mxl_chunk_11...
# Procesing bwv20.7.mxl_chunk_12...
# Procesing bwv20.7.mxl_chunk_2...
# Procesing bwv20.7.mxl_chunk_3...
# Procesing bwv20.7.mxl_chunk_4...
# Procesing bwv20.7.mxl_chunk_5...
# Procesing bwv20.7.mxl_chunk_6...
# Procesing bwv20.7.mxl_chunk_7...
# Procesing bwv20.7.mxl_chunk_8...
# Procesing bwv20.7.mxl_chunk_9...
# Procesing bwv226.2.mxl_chunk_0...
# Procesing bwv226.2.mxl_chunk_1...
# Procesing bwv226.2.mxl_chunk_10...
# Procesing bwv226.2.mxl_chunk_11...
# Procesing bwv226.2.mxl_chunk_12...
# Procesing bwv226.2.mxl_chunk_13...
# Procesing bwv226.2.mxl_chunk_14...
# Procesing bwv226.2.mxl_chunk_15...
# Procesing bwv226.2.mxl_chunk_16...
# Procesing bwv226.2.mxl_chunk_17...
# Procesing bwv226.2.mxl_chunk_18...
# Procesing bwv226.2.mxl_chunk_19...
# Procesing bwv226.2.mxl_chunk_2...
# Procesing bwv226.2.mxl_chunk_20...
# Procesing bwv226.2.mxl_chunk_21...
# Procesing bwv226.2.mxl_chunk_22...
# Procesing bwv226.2.mxl_chunk_23...
# Procesing bwv226.2.mxl_chunk_3...
# Procesing bwv226.2.mxl_chunk_4...
# Procesing bwv226.2.mxl_chunk_5...
# Procesing bwv226.2.mxl_chunk_6...
# Procesing bwv226.2.mxl_chunk_7...
# Procesing bwv226.2.mxl_chunk_8...
# Procesing bwv226.2.mxl_chunk_9...
# Procesing bwv227.1.mxl_chunk_0...
# Procesing bwv227.1.mxl_chunk_1...
# Procesing bwv227.1.mxl_chunk_10...
# Procesing bwv227.1.mxl_chunk_11...
# Procesing bwv227.1.mxl_chunk_12...
# Procesing bwv227.1.mxl_chunk_13...
# Procesing bwv227.1.mxl_chunk_14...
# Procesing bwv227.1.mxl_chunk_15...
# Procesing bwv227.1.mxl_chunk_2...
# Procesing bwv227.1.mxl_chunk_3...
# Procesing bwv227.1.mxl_chunk_4...
# Procesing bwv227.1.mxl_chunk_5...
# Procesing bwv227.1.mxl_chunk_6...
# Procesing bwv227.1.mxl_chunk_7...
# Procesing bwv227.1.mxl_chunk_8...
# Procesing bwv227.1.mxl_chunk_9...
# Procesing bwv227.11.mxl_chunk_0...
# Procesing bwv227.11.mxl_chunk_1...
# Procesing bwv227.11.mxl_chunk_2...
# Procesing bwv227.11.mxl_chunk_3...
# Procesing bwv227.11.mxl_chunk_4...
# Procesing bwv227.11.mxl_chunk_5...
# Procesing bwv227.11.mxl_chunk_6...
# Procesing bwv227.11.mxl_chunk_7...
# Procesing bwv227.11.mxl_chunk_8...
# Procesing bwv227.11.mxl_chunk_9...
# Procesing bwv227.7.mxl_chunk_0...
# Procesing bwv227.7.mxl_chunk_1...
# Procesing bwv227.7.mxl_chunk_2...
# Procesing bwv227.7.mxl_chunk_3...
# Procesing bwv227.7.mxl_chunk_4...
# Procesing bwv227.7.mxl_chunk_5...
# Procesing bwv227.7.mxl_chunk_6...
# Procesing bwv227.7.mxl_chunk_7...
# Procesing bwv227.7.mxl_chunk_8...
# Procesing bwv227.7.mxl_chunk_9...
# Procesing bwv229.2.mxl_chunk_0...
# Procesing bwv229.2.mxl_chunk_1...
# Procesing bwv229.2.mxl_chunk_10...
# Procesing bwv229.2.mxl_chunk_11...
# Procesing bwv229.2.mxl_chunk_12...
# Procesing bwv229.2.mxl_chunk_13...
# Procesing bwv229.2.mxl_chunk_14...
# Procesing bwv229.2.mxl_chunk_15...
# Procesing bwv229.2.mxl_chunk_16...
# Procesing bwv229.2.mxl_chunk_17...
# Procesing bwv229.2.mxl_chunk_18...
# Procesing bwv229.2.mxl_chunk_19...
# Procesing bwv229.2.mxl_chunk_2...
# Procesing bwv229.2.mxl_chunk_20...
# Procesing bwv229.2.mxl_chunk_21...
# Procesing bwv229.2.mxl_chunk_22...
# Procesing bwv229.2.mxl_chunk_23...
# Procesing bwv229.2.mxl_chunk_24...
# Procesing bwv229.2.mxl_chunk_3...
# Procesing bwv229.2.mxl_chunk_4...
# Procesing bwv229.2.mxl_chunk_5...
# Procesing bwv229.2.mxl_chunk_6...
# Procesing bwv229.2.mxl_chunk_7...
# Procesing bwv229.2.mxl_chunk_8...
# Procesing bwv229.2.mxl_chunk_9...
# Procesing bwv24.6.mxl_chunk_0...
# Procesing bwv24.6.mxl_chunk_1...
# Procesing bwv24.6.mxl_chunk_2...
# Procesing bwv24.6.mxl_chunk_3...
# Procesing bwv24.6.mxl_chunk_4...
# Procesing bwv24.6.mxl_chunk_5...
# Procesing bwv24.6.mxl_chunk_6...
# Procesing bwv24.6.mxl_chunk_7...
# Procesing bwv24.6.mxl_chunk_8...
# Procesing bwv24.6.mxl_chunk_9...
# Procesing bwv244.10.mxl_chunk_0...
# Procesing bwv244.10.mxl_chunk_1...
# Procesing bwv244.10.mxl_chunk_2...
# Procesing bwv244.10.mxl_chunk_3...
# Procesing bwv244.10.mxl_chunk_4...
# Procesing bwv244.10.mxl_chunk_5...
# Procesing bwv244.10.mxl_chunk_6...
# Procesing bwv244.10.mxl_chunk_7...
# Procesing bwv244.10.mxl_chunk_8...
# Procesing bwv244.15.mxl_chunk_0...
# Procesing bwv244.15.mxl_chunk_1...
# Procesing bwv244.15.mxl_chunk_10...
# Procesing bwv244.15.mxl_chunk_2...
# Procesing bwv244.15.mxl_chunk_3...
# Procesing bwv244.15.mxl_chunk_4...
# Procesing bwv244.15.mxl_chunk_5...
# Procesing bwv244.15.mxl_chunk_6...
# Procesing bwv244.15.mxl_chunk_7...
# Procesing bwv244.15.mxl_chunk_8...
# Procesing bwv244.15.mxl_chunk_9...
# Procesing bwv244.17.mxl_chunk_0...
# Procesing bwv244.17.mxl_chunk_1...
# Procesing bwv244.17.mxl_chunk_10...
# Procesing bwv244.17.mxl_chunk_11...
# Procesing bwv244.17.mxl_chunk_12...
# Procesing bwv244.17.mxl_chunk_2...
# Procesing bwv244.17.mxl_chunk_3...
# Procesing bwv244.17.mxl_chunk_4...
# Procesing bwv244.17.mxl_chunk_5...
# Procesing bwv244.17.mxl_chunk_6...
# Procesing bwv244.17.mxl_chunk_7...
# Procesing bwv244.17.mxl_chunk_8...
# Procesing bwv244.17.mxl_chunk_9...
# Procesing bwv244.25.mxl_chunk_0...
# Procesing bwv244.25.mxl_chunk_1...
# Procesing bwv244.25.mxl_chunk_10...
# Procesing bwv244.25.mxl_chunk_2...
# Procesing bwv244.25.mxl_chunk_3...
# Procesing bwv244.25.mxl_chunk_4...
# Procesing bwv244.25.mxl_chunk_5...
# Procesing bwv244.25.mxl_chunk_6...
# Procesing bwv244.25.mxl_chunk_7...
# Procesing bwv244.25.mxl_chunk_8...
# Procesing bwv244.25.mxl_chunk_9...
# Procesing bwv244.29-a.mxl_chunk_0...
# Procesing bwv244.29-a.mxl_chunk_1...
# Procesing bwv244.29-a.mxl_chunk_2...
# Procesing bwv244.29-a.mxl_chunk_3...
# Procesing bwv244.29-a.mxl_chunk_4...
# Procesing bwv244.29-a.mxl_chunk_5...
# Procesing bwv244.29-a.mxl_chunk_6...
# Procesing bwv244.29-a.mxl_chunk_7...
# Procesing bwv244.29-a.mxl_chunk_8...
# Procesing bwv244.29-a.mxl_chunk_9...
# Procesing bwv244.3.mxl_chunk_0...
# Procesing bwv244.3.mxl_chunk_1...
# Procesing bwv244.3.mxl_chunk_2...
# Procesing bwv244.3.mxl_chunk_3...
# Procesing bwv244.3.mxl_chunk_4...
# Procesing bwv244.3.mxl_chunk_5...
# Procesing bwv244.3.mxl_chunk_6...
# Procesing bwv244.3.mxl_chunk_7...
# Procesing bwv244.32.mxl_chunk_0...
# Procesing bwv244.32.mxl_chunk_1...
# Procesing bwv244.32.mxl_chunk_2...
# Procesing bwv244.32.mxl_chunk_3...
# Procesing bwv244.32.mxl_chunk_4...
# Procesing bwv244.32.mxl_chunk_5...
# Procesing bwv244.32.mxl_chunk_6...
# Procesing bwv244.32.mxl_chunk_7...
# Procesing bwv244.37.mxl_chunk_0...
# Procesing bwv244.37.mxl_chunk_1...
# Procesing bwv244.37.mxl_chunk_10...
# Procesing bwv244.37.mxl_chunk_2...
# Procesing bwv244.37.mxl_chunk_3...
# Procesing bwv244.37.mxl_chunk_4...
# Procesing bwv244.37.mxl_chunk_5...
# Procesing bwv244.37.mxl_chunk_6...
# Procesing bwv244.37.mxl_chunk_7...
# Procesing bwv244.37.mxl_chunk_8...
# Procesing bwv244.37.mxl_chunk_9...
# Procesing bwv244.40.mxl_chunk_0...
# Procesing bwv244.40.mxl_chunk_1...
# Procesing bwv244.40.mxl_chunk_10...
# Procesing bwv244.40.mxl_chunk_11...
# Procesing bwv244.40.mxl_chunk_12...
# Procesing bwv244.40.mxl_chunk_2...
# Procesing bwv244.40.mxl_chunk_3...
# Procesing bwv244.40.mxl_chunk_4...
# Procesing bwv244.40.mxl_chunk_5...
# Procesing bwv244.40.mxl_chunk_6...
# Procesing bwv244.40.mxl_chunk_7...
# Procesing bwv244.40.mxl_chunk_8...
# Procesing bwv244.40.mxl_chunk_9...
# Procesing bwv244.44.mxl_chunk_0...
# Procesing bwv244.44.mxl_chunk_1...
# Procesing bwv244.44.mxl_chunk_10...
# Procesing bwv244.44.mxl_chunk_2...
# Procesing bwv244.44.mxl_chunk_3...
# Procesing bwv244.44.mxl_chunk_4...
# Procesing bwv244.44.mxl_chunk_5...
# Procesing bwv244.44.mxl_chunk_6...
# Procesing bwv244.44.mxl_chunk_7...
# Procesing bwv244.44.mxl_chunk_8...
# Procesing bwv244.44.mxl_chunk_9...
# Procesing bwv244.46.mxl_chunk_0...
# Procesing bwv244.46.mxl_chunk_1...
# Procesing bwv244.46.mxl_chunk_2...
# Procesing bwv244.46.mxl_chunk_3...
# Procesing bwv244.46.mxl_chunk_4...
# Procesing bwv244.46.mxl_chunk_5...
# Procesing bwv244.46.mxl_chunk_6...
# Procesing bwv244.46.mxl_chunk_7...
# Procesing bwv244.54.mxl_chunk_0...
# Procesing bwv244.54.mxl_chunk_1...
# Procesing bwv244.54.mxl_chunk_10...
# Procesing bwv244.54.mxl_chunk_2...
# Procesing bwv244.54.mxl_chunk_3...
# Procesing bwv244.54.mxl_chunk_4...
# Procesing bwv244.54.mxl_chunk_5...
# Procesing bwv244.54.mxl_chunk_6...
# Procesing bwv244.54.mxl_chunk_7...
# Procesing bwv244.54.mxl_chunk_8...
# Procesing bwv244.54.mxl_chunk_9...
# Procesing bwv244.62.mxl_chunk_0...
# Procesing bwv244.62.mxl_chunk_1...
# Procesing bwv244.62.mxl_chunk_10...
# Procesing bwv244.62.mxl_chunk_2...
# Procesing bwv244.62.mxl_chunk_3...
# Procesing bwv244.62.mxl_chunk_4...
# Procesing bwv244.62.mxl_chunk_5...
# Procesing bwv244.62.mxl_chunk_6...
# Procesing bwv244.62.mxl_chunk_7...
# Procesing bwv244.62.mxl_chunk_8...
# Procesing bwv244.62.mxl_chunk_9...
# Procesing bwv245.11.mxl_chunk_0...
# Procesing bwv245.11.mxl_chunk_1...
# Procesing bwv245.11.mxl_chunk_10...
# Procesing bwv245.11.mxl_chunk_2...
# Procesing bwv245.11.mxl_chunk_3...
# Procesing bwv245.11.mxl_chunk_4...
# Procesing bwv245.11.mxl_chunk_5...
# Procesing bwv245.11.mxl_chunk_6...
# Procesing bwv245.11.mxl_chunk_7...
# Procesing bwv245.11.mxl_chunk_8...
# Procesing bwv245.11.mxl_chunk_9...
# Procesing bwv245.14.mxl_chunk_0...
# Procesing bwv245.14.mxl_chunk_1...
# Procesing bwv245.14.mxl_chunk_10...
# Procesing bwv245.14.mxl_chunk_11...
# Procesing bwv245.14.mxl_chunk_12...
# Procesing bwv245.14.mxl_chunk_2...
# Procesing bwv245.14.mxl_chunk_3...
# Procesing bwv245.14.mxl_chunk_4...
# Procesing bwv245.14.mxl_chunk_5...
# Procesing bwv245.14.mxl_chunk_6...
# Procesing bwv245.14.mxl_chunk_7...
# Procesing bwv245.14.mxl_chunk_8...
# Procesing bwv245.14.mxl_chunk_9...
# Procesing bwv245.15.mxl_chunk_0...
# Procesing bwv245.15.mxl_chunk_1...
# Procesing bwv245.15.mxl_chunk_10...
# Procesing bwv245.15.mxl_chunk_11...
# Procesing bwv245.15.mxl_chunk_12...
# Procesing bwv245.15.mxl_chunk_13...
# Procesing bwv245.15.mxl_chunk_2...
# Procesing bwv245.15.mxl_chunk_3...
# Procesing bwv245.15.mxl_chunk_4...
# Procesing bwv245.15.mxl_chunk_5...
# Procesing bwv245.15.mxl_chunk_6...
# Procesing bwv245.15.mxl_chunk_7...
# Procesing bwv245.15.mxl_chunk_8...
# Procesing bwv245.15.mxl_chunk_9...
# Procesing bwv245.17.mxl_chunk_0...
# Procesing bwv245.17.mxl_chunk_1...
# Procesing bwv245.17.mxl_chunk_2...
# Procesing bwv245.17.mxl_chunk_3...
# Procesing bwv245.17.mxl_chunk_4...
# Procesing bwv245.17.mxl_chunk_5...
# Procesing bwv245.17.mxl_chunk_6...
# Procesing bwv245.17.mxl_chunk_7...
# Procesing bwv245.17.mxl_chunk_8...
# Procesing bwv245.17.mxl_chunk_9...
# Procesing bwv245.22.mxl_chunk_0...
# Procesing bwv245.22.mxl_chunk_1...
# Procesing bwv245.22.mxl_chunk_2...
# Procesing bwv245.22.mxl_chunk_3...
# Procesing bwv245.22.mxl_chunk_4...
# Procesing bwv245.22.mxl_chunk_5...
# Procesing bwv245.26.mxl_chunk_0...
# Procesing bwv245.26.mxl_chunk_1...
# Procesing bwv245.26.mxl_chunk_10...
# Procesing bwv245.26.mxl_chunk_2...
# Procesing bwv245.26.mxl_chunk_3...
# Procesing bwv245.26.mxl_chunk_4...
# Procesing bwv245.26.mxl_chunk_5...
# Procesing bwv245.26.mxl_chunk_6...
# Procesing bwv245.26.mxl_chunk_7...
# Procesing bwv245.26.mxl_chunk_8...
# Procesing bwv245.26.mxl_chunk_9...
# Procesing bwv245.28.mxl_chunk_0...
# Procesing bwv245.28.mxl_chunk_1...
# Procesing bwv245.28.mxl_chunk_10...
# Procesing bwv245.28.mxl_chunk_11...
# Procesing bwv245.28.mxl_chunk_12...
# Procesing bwv245.28.mxl_chunk_2...
# Procesing bwv245.28.mxl_chunk_3...
# Procesing bwv245.28.mxl_chunk_4...
# Procesing bwv245.28.mxl_chunk_5...
# Procesing bwv245.28.mxl_chunk_6...
# Procesing bwv245.28.mxl_chunk_7...
# Procesing bwv245.28.mxl_chunk_8...
# Procesing bwv245.28.mxl_chunk_9...
# Procesing bwv245.3.mxl_chunk_0...
# Procesing bwv245.3.mxl_chunk_1...
# Procesing bwv245.3.mxl_chunk_2...
# Procesing bwv245.3.mxl_chunk_3...
# Procesing bwv245.3.mxl_chunk_4...
# Procesing bwv245.3.mxl_chunk_5...
# Procesing bwv245.3.mxl_chunk_6...
# Procesing bwv245.3.mxl_chunk_7...
# Procesing bwv245.37.mxl_chunk_0...
# Procesing bwv245.37.mxl_chunk_1...
# Procesing bwv245.37.mxl_chunk_10...
# Procesing bwv245.37.mxl_chunk_11...
# Procesing bwv245.37.mxl_chunk_12...
# Procesing bwv245.37.mxl_chunk_13...
# Procesing bwv245.37.mxl_chunk_2...
# Procesing bwv245.37.mxl_chunk_3...
# Procesing bwv245.37.mxl_chunk_4...
# Procesing bwv245.37.mxl_chunk_5...
# Procesing bwv245.37.mxl_chunk_6...
# Procesing bwv245.37.mxl_chunk_7...
# Procesing bwv245.37.mxl_chunk_8...
# Procesing bwv245.37.mxl_chunk_9...
# Procesing bwv245.40.mxl_chunk_0...
# Procesing bwv245.40.mxl_chunk_1...
# Procesing bwv245.40.mxl_chunk_10...
# Procesing bwv245.40.mxl_chunk_11...
# Procesing bwv245.40.mxl_chunk_12...
# Procesing bwv245.40.mxl_chunk_13...
# Procesing bwv245.40.mxl_chunk_14...
# Procesing bwv245.40.mxl_chunk_15...
# Procesing bwv245.40.mxl_chunk_16...
# Procesing bwv245.40.mxl_chunk_17...
# Procesing bwv245.40.mxl_chunk_18...
# Procesing bwv245.40.mxl_chunk_19...
# Procesing bwv245.40.mxl_chunk_2...
# Procesing bwv245.40.mxl_chunk_20...
# Procesing bwv245.40.mxl_chunk_21...
# Procesing bwv245.40.mxl_chunk_22...
# Procesing bwv245.40.mxl_chunk_23...
# Procesing bwv245.40.mxl_chunk_24...
# Procesing bwv245.40.mxl_chunk_3...
# Procesing bwv245.40.mxl_chunk_4...
# Procesing bwv245.40.mxl_chunk_5...
# Procesing bwv245.40.mxl_chunk_6...
# Procesing bwv245.40.mxl_chunk_7...
# Procesing bwv245.40.mxl_chunk_8...
# Procesing bwv245.40.mxl_chunk_9...
# Procesing bwv245.5.mxl_chunk_0...
# Procesing bwv245.5.mxl_chunk_1...
# Procesing bwv245.5.mxl_chunk_2...
# Procesing bwv245.5.mxl_chunk_3...
# Procesing bwv245.5.mxl_chunk_4...
# Procesing bwv245.5.mxl_chunk_5...
# Procesing bwv245.5.mxl_chunk_6...
# Procesing bwv245.5.mxl_chunk_7...
# Procesing bwv245.5.mxl_chunk_8...
# Procesing bwv248.12-2.mxl_chunk_0...
# Procesing bwv248.12-2.mxl_chunk_1...
# Procesing bwv248.12-2.mxl_chunk_10...
# Procesing bwv248.12-2.mxl_chunk_2...
# Procesing bwv248.12-2.mxl_chunk_3...
# Procesing bwv248.12-2.mxl_chunk_4...
# Procesing bwv248.12-2.mxl_chunk_5...
# Procesing bwv248.12-2.mxl_chunk_6...
# Procesing bwv248.12-2.mxl_chunk_7...
# Procesing bwv248.12-2.mxl_chunk_8...
# Procesing bwv248.12-2.mxl_chunk_9...
# Procesing bwv248.23-s.mxl_chunk_0...
# Procesing bwv248.23-s.mxl_chunk_1...
# Procesing bwv248.23-s.mxl_chunk_2...
# Procesing bwv248.23-s.mxl_chunk_3...
# Procesing bwv248.23-s.mxl_chunk_4...
# Procesing bwv248.28.mxl_chunk_0...
# Procesing bwv248.28.mxl_chunk_1...
# Procesing bwv248.28.mxl_chunk_2...
# Procesing bwv248.28.mxl_chunk_3...
# Procesing bwv248.28.mxl_chunk_4...
# Procesing bwv248.28.mxl_chunk_5...
# Procesing bwv248.28.mxl_chunk_6...
# Procesing bwv248.33-3.mxl_chunk_0...
# Procesing bwv248.33-3.mxl_chunk_1...
# Procesing bwv248.33-3.mxl_chunk_10...
# Procesing bwv248.33-3.mxl_chunk_2...
# Procesing bwv248.33-3.mxl_chunk_3...
# Procesing bwv248.33-3.mxl_chunk_4...
# Procesing bwv248.33-3.mxl_chunk_5...
# Procesing bwv248.33-3.mxl_chunk_6...
# Procesing bwv248.33-3.mxl_chunk_7...
# Procesing bwv248.33-3.mxl_chunk_8...
# Procesing bwv248.33-3.mxl_chunk_9...
# Procesing bwv248.35-3.mxl_chunk_0...
# Procesing bwv248.35-3.mxl_chunk_1...
# Procesing bwv248.35-3.mxl_chunk_2...
# Procesing bwv248.35-3.mxl_chunk_3...
# Procesing bwv248.35-3.mxl_chunk_4...
# Procesing bwv248.35-3.mxl_chunk_5...
# Procesing bwv248.35-3.mxl_chunk_6...
# Procesing bwv248.35-3.mxl_chunk_7...
# Procesing bwv248.35-3.mxl_chunk_8...
# Procesing bwv248.35-3.mxl_chunk_9...
# Procesing bwv248.42-s.mxl_chunk_0...
# Procesing bwv248.42-s.mxl_chunk_1...
# Procesing bwv248.42-s.mxl_chunk_10...
# Procesing bwv248.42-s.mxl_chunk_11...
# Procesing bwv248.42-s.mxl_chunk_12...
# Procesing bwv248.42-s.mxl_chunk_13...
# Procesing bwv248.42-s.mxl_chunk_14...
# Procesing bwv248.42-s.mxl_chunk_15...
# Procesing bwv248.42-s.mxl_chunk_16...
# Procesing bwv248.42-s.mxl_chunk_17...
# Procesing bwv248.42-s.mxl_chunk_18...
# Procesing bwv248.42-s.mxl_chunk_19...
# Procesing bwv248.42-s.mxl_chunk_2...
# Procesing bwv248.42-s.mxl_chunk_20...
# ...
# Procesing bwv46.6.mxl_chunk_0...
# Procesing bwv46.6.mxl_chunk_1...
# Procesing bwv46.6.mxl_chunk_10...
# Procesing bwv46.6.mxl_chunk_11...
# Procesing bwv46.6.mxl_chunk_12...
# Procesing bwv46.6.mxl_chunk_13...
# Procesing bwv46.6.mxl_chunk_14...
# Procesing bwv46.6.mxl_chunk_2...
# Procesing bwv46.6.mxl_chunk_3...
# Procesing bwv46.6.mxl_chunk_4...
# Procesing bwv46.6.mxl_chunk_5...
# Procesing bwv46.6.mxl_chunk_6...
# Procesing bwv46.6.mxl_chunk_7...
# Procesing bwv46.6.mxl_chunk_8...
# Procesing bwv46.6.mxl_chunk_9...
# Procesing bwv47.5.mxl_chunk_0...
# Procesing bwv47.5.mxl_chunk_1...
# Procesing bwv47.5.mxl_chunk_2...
# Procesing bwv47.5.mxl_chunk_3...
# Procesing bwv47.5.mxl_chunk_4...
# Procesing bwv47.5.mxl_chunk_5...
# Procesing bwv47.5.mxl_chunk_6...
# Procesing bwv47.5.mxl_chunk_7...
# Procesing bwv47.5.mxl_chunk_8...
# Procesing bwv48.3.mxl_chunk_0...
# Procesing bwv48.3.mxl_chunk_1...
# Procesing bwv48.3.mxl_chunk_2...
# Procesing bwv48.3.mxl_chunk_3...
# Procesing bwv48.3.mxl_chunk_4...
# Procesing bwv48.3.mxl_chunk_5...
# Procesing bwv48.3.mxl_chunk_6...
# Procesing bwv48.3.mxl_chunk_7...
# Procesing bwv48.7.mxl_chunk_0...
# Procesing bwv48.7.mxl_chunk_1...
# Procesing bwv48.7.mxl_chunk_2...
# Procesing bwv48.7.mxl_chunk_3...
# Procesing bwv48.7.mxl_chunk_4...
# Procesing bwv48.7.mxl_chunk_5...
# Procesing bwv48.7.mxl_chunk_6...
# Procesing bwv48.7.mxl_chunk_7...
# Procesing bwv48.7.mxl_chunk_8...
# Procesing bwv48.7.mxl_chunk_9...
# Procesing bwv5.7.mxl_chunk_0...
# Procesing bwv5.7.mxl_chunk_1...
# Procesing bwv5.7.mxl_chunk_10...
# Procesing bwv5.7.mxl_chunk_2...
# Procesing bwv5.7.mxl_chunk_3...
# Procesing bwv5.7.mxl_chunk_4...
# Procesing bwv5.7.mxl_chunk_5...
# Procesing bwv5.7.mxl_chunk_6...
# Procesing bwv5.7.mxl_chunk_7...
# Procesing bwv5.7.mxl_chunk_8...
# Procesing bwv5.7.mxl_chunk_9...
# Procesing bwv55.5.mxl_chunk_0...
# Procesing bwv55.5.mxl_chunk_1...
# Procesing bwv55.5.mxl_chunk_2...
# Procesing bwv55.5.mxl_chunk_3...
# Procesing bwv55.5.mxl_chunk_4...
# Procesing bwv55.5.mxl_chunk_5...
# Procesing bwv55.5.mxl_chunk_6...
# Procesing bwv55.5.mxl_chunk_7...
# Procesing bwv55.5.mxl_chunk_8...
# Procesing bwv56.5.mxl_chunk_0...
# Procesing bwv56.5.mxl_chunk_1...
# Procesing bwv56.5.mxl_chunk_2...
# Procesing bwv56.5.mxl_chunk_3...
# Procesing bwv56.5.mxl_chunk_4...
# Procesing bwv56.5.mxl_chunk_5...
# Procesing bwv56.5.mxl_chunk_6...
# Procesing bwv56.5.mxl_chunk_7...
# Procesing bwv56.5.mxl_chunk_8...
# Procesing bwv56.5.mxl_chunk_9...
# Procesing bwv57.8.mxl_chunk_0...
# Procesing bwv57.8.mxl_chunk_1...
# Procesing bwv57.8.mxl_chunk_2...
# Procesing bwv57.8.mxl_chunk_3...
# Procesing bwv57.8.mxl_chunk_4...
# Procesing bwv57.8.mxl_chunk_5...
# Procesing bwv57.8.mxl_chunk_6...
# Procesing bwv57.8.mxl_chunk_7...
# Procesing bwv57.8.mxl_chunk_8...
# Procesing bwv57.8.mxl_chunk_9...
# Procesing bwv6.6.mxl_chunk_0...
# Procesing bwv6.6.mxl_chunk_1...
# Procesing bwv6.6.mxl_chunk_2...
# Procesing bwv6.6.mxl_chunk_3...
# Procesing bwv6.6.mxl_chunk_4...
# Procesing bwv6.6.mxl_chunk_5...
# Procesing bwv60.5.mxl_chunk_0...
# Procesing bwv60.5.mxl_chunk_1...
# Procesing bwv60.5.mxl_chunk_10...
# Procesing bwv60.5.mxl_chunk_11...
# Procesing bwv60.5.mxl_chunk_12...
# Procesing bwv60.5.mxl_chunk_13...
# Procesing bwv60.5.mxl_chunk_14...
# Procesing bwv60.5.mxl_chunk_15...
# Procesing bwv60.5.mxl_chunk_16...
# Procesing bwv60.5.mxl_chunk_2...
# Procesing bwv60.5.mxl_chunk_3...
# Procesing bwv60.5.mxl_chunk_4...
# Procesing bwv60.5.mxl_chunk_5...
# Procesing bwv60.5.mxl_chunk_6...
# Procesing bwv60.5.mxl_chunk_7...
# Procesing bwv60.5.mxl_chunk_8...
# Procesing bwv60.5.mxl_chunk_9...
# Procesing bwv62.6.mxl_chunk_0...
# Procesing bwv62.6.mxl_chunk_1...
# Procesing bwv62.6.mxl_chunk_2...
# Procesing bwv62.6.mxl_chunk_3...
# Procesing bwv62.6.mxl_chunk_4...
# Procesing bwv62.6.mxl_chunk_5...
# Procesing bwv64.2.mxl_chunk_0...
# Procesing bwv64.2.mxl_chunk_1...
# Procesing bwv64.2.mxl_chunk_2...
# Procesing bwv64.2.mxl_chunk_3...
# Procesing bwv64.2.mxl_chunk_4...
# Procesing bwv64.2.mxl_chunk_5...
# Procesing bwv64.2.mxl_chunk_6...
# Procesing bwv64.2.mxl_chunk_7...
# Procesing bwv64.4.mxl_chunk_0...
# Procesing bwv64.4.mxl_chunk_1...
# Procesing bwv64.4.mxl_chunk_10...
# Procesing bwv64.4.mxl_chunk_11...
# Procesing bwv64.4.mxl_chunk_12...
# Procesing bwv64.4.mxl_chunk_13...
# Procesing bwv64.4.mxl_chunk_14...
# Procesing bwv64.4.mxl_chunk_2...
# Procesing bwv64.4.mxl_chunk_3...
# Procesing bwv64.4.mxl_chunk_4...
# Procesing bwv64.4.mxl_chunk_5...
# Procesing bwv64.4.mxl_chunk_6...
# Procesing bwv64.4.mxl_chunk_7...
# Procesing bwv64.4.mxl_chunk_8...
# Procesing bwv64.4.mxl_chunk_9...
# Procesing bwv64.8.mxl_chunk_0...
# Procesing bwv64.8.mxl_chunk_1...
# Procesing bwv64.8.mxl_chunk_2...
# Procesing bwv64.8.mxl_chunk_3...
# Procesing bwv64.8.mxl_chunk_4...
# Procesing bwv64.8.mxl_chunk_5...
# Procesing bwv64.8.mxl_chunk_6...
# Procesing bwv64.8.mxl_chunk_7...
# Procesing bwv64.8.mxl_chunk_8...
# Procesing bwv64.8.mxl_chunk_9...
# Procesing bwv65.2.mxl_chunk_0...
# Procesing bwv65.2.mxl_chunk_1...
# Procesing bwv65.2.mxl_chunk_10...
# Procesing bwv65.2.mxl_chunk_11...
# Procesing bwv65.2.mxl_chunk_12...
# Procesing bwv65.2.mxl_chunk_2...
# Procesing bwv65.2.mxl_chunk_3...
# Procesing bwv65.2.mxl_chunk_4...
# Procesing bwv65.2.mxl_chunk_5...
# Procesing bwv65.2.mxl_chunk_6...
# Procesing bwv65.2.mxl_chunk_7...
# Procesing bwv65.2.mxl_chunk_8...
# Procesing bwv65.2.mxl_chunk_9...
# Procesing bwv65.7.mxl_chunk_0...
# Procesing bwv65.7.mxl_chunk_1...
# Procesing bwv65.7.mxl_chunk_10...
# Procesing bwv65.7.mxl_chunk_11...
# Procesing bwv65.7.mxl_chunk_2...
# Procesing bwv65.7.mxl_chunk_3...
# Procesing bwv65.7.mxl_chunk_4...
# Procesing bwv65.7.mxl_chunk_5...
# Procesing bwv65.7.mxl_chunk_6...
# Procesing bwv65.7.mxl_chunk_7...
# Procesing bwv65.7.mxl_chunk_8...
# Procesing bwv65.7.mxl_chunk_9...
# Procesing bwv66.6.mxl_chunk_0...
# Procesing bwv66.6.mxl_chunk_1...
# Procesing bwv66.6.mxl_chunk_2...
# Procesing bwv66.6.mxl_chunk_3...
# Procesing bwv66.6.mxl_chunk_4...
# Procesing bwv66.6.mxl_chunk_5...
# Procesing bwv67.4.xml_chunk_0...
# Procesing bwv67.4.xml_chunk_1...
# Procesing bwv67.4.xml_chunk_10...
# Procesing bwv67.4.xml_chunk_11...
# Procesing bwv67.4.xml_chunk_12...
# Procesing bwv67.4.xml_chunk_13...
# Procesing bwv67.4.xml_chunk_14...
# Procesing bwv67.4.xml_chunk_2...
# Procesing bwv67.4.xml_chunk_3...
# Procesing bwv67.4.xml_chunk_4...
# Procesing bwv67.4.xml_chunk_5...
# Procesing bwv67.4.xml_chunk_6...
# Procesing bwv67.4.xml_chunk_7...
# Procesing bwv67.4.xml_chunk_8...
# Procesing bwv67.4.xml_chunk_9...
# Procesing bwv67.7.mxl_chunk_0...
# Procesing bwv67.7.mxl_chunk_1...
# Procesing bwv67.7.mxl_chunk_2...
# Procesing bwv67.7.mxl_chunk_3...
# Procesing bwv67.7.mxl_chunk_4...
# Procesing bwv67.7.mxl_chunk_5...
# Procesing bwv67.7.mxl_chunk_6...
# Procesing bwv69.6-a.mxl_chunk_0...
# Procesing bwv69.6-a.mxl_chunk_1...
# Procesing bwv69.6-a.mxl_chunk_2...
# Procesing bwv69.6-a.mxl_chunk_3...
# Procesing bwv69.6-a.mxl_chunk_4...
# Procesing bwv69.6-a.mxl_chunk_5...
# Procesing bwv69.6-a.mxl_chunk_6...
# Procesing bwv69.6-a.mxl_chunk_7...
# Procesing bwv69.6-a.mxl_chunk_8...
# Procesing bwv7.7.mxl_chunk_0...
# Procesing bwv7.7.mxl_chunk_1...
# Procesing bwv7.7.mxl_chunk_10...
# Procesing bwv7.7.mxl_chunk_11...
# Procesing bwv7.7.mxl_chunk_12...
# Procesing bwv7.7.mxl_chunk_13...
# Procesing bwv7.7.mxl_chunk_14...
# Procesing bwv7.7.mxl_chunk_2...
# Procesing bwv7.7.mxl_chunk_3...
# Procesing bwv7.7.mxl_chunk_4...
# Procesing bwv7.7.mxl_chunk_5...
# Procesing bwv7.7.mxl_chunk_6...
# Procesing bwv7.7.mxl_chunk_7...
# Procesing bwv7.7.mxl_chunk_8...
# Procesing bwv7.7.mxl_chunk_9...
# Procesing bwv70.7.mxl_chunk_0...
# Procesing bwv70.7.mxl_chunk_1...
# Procesing bwv70.7.mxl_chunk_10...
# Procesing bwv70.7.mxl_chunk_11...
# Procesing bwv70.7.mxl_chunk_12...
# Procesing bwv70.7.mxl_chunk_13...
# Procesing bwv70.7.mxl_chunk_14...
# Procesing bwv70.7.mxl_chunk_15...
# Procesing bwv70.7.mxl_chunk_16...
# Procesing bwv70.7.mxl_chunk_17...
# Procesing bwv70.7.mxl_chunk_18...
# Procesing bwv70.7.mxl_chunk_19...
# Procesing bwv70.7.mxl_chunk_2...
# Procesing bwv70.7.mxl_chunk_20...
# Procesing bwv70.7.mxl_chunk_21...
# Procesing bwv70.7.mxl_chunk_22...
# Procesing bwv70.7.mxl_chunk_23...
# Procesing bwv70.7.mxl_chunk_24...
# Procesing bwv70.7.mxl_chunk_25...
# Procesing bwv70.7.mxl_chunk_26...
# Procesing bwv70.7.mxl_chunk_27...
# Procesing bwv70.7.mxl_chunk_28...
# Procesing bwv70.7.mxl_chunk_29...
# Procesing bwv70.7.mxl_chunk_3...
# Procesing bwv70.7.mxl_chunk_30...
# Procesing bwv70.7.mxl_chunk_4...
# Procesing bwv70.7.mxl_chunk_5...
# Procesing bwv70.7.mxl_chunk_6...
# Procesing bwv70.7.mxl_chunk_7...
# Procesing bwv70.7.mxl_chunk_8...
# Procesing bwv70.7.mxl_chunk_9...
# Procesing bwv72.6.mxl_chunk_0...
# Procesing bwv72.6.mxl_chunk_1...
# Procesing bwv72.6.mxl_chunk_10...
# Procesing bwv72.6.mxl_chunk_11...
# Procesing bwv72.6.mxl_chunk_12...
# Procesing bwv72.6.mxl_chunk_13...
# Procesing bwv72.6.mxl_chunk_14...
# Procesing bwv72.6.mxl_chunk_15...
# Procesing bwv72.6.mxl_chunk_2...
# Procesing bwv72.6.mxl_chunk_3...
# Procesing bwv72.6.mxl_chunk_4...
# Procesing bwv72.6.mxl_chunk_5...
# Procesing bwv72.6.mxl_chunk_6...
# Procesing bwv72.6.mxl_chunk_7...
# Procesing bwv72.6.mxl_chunk_8...
# Procesing bwv72.6.mxl_chunk_9...
# Procesing bwv73.5.mxl_chunk_0...
# Procesing bwv73.5.mxl_chunk_1...
# Procesing bwv73.5.mxl_chunk_10...
# Procesing bwv73.5.mxl_chunk_2...
# Procesing bwv73.5.mxl_chunk_3...
# Procesing bwv73.5.mxl_chunk_4...
# Procesing bwv73.5.mxl_chunk_5...
# Procesing bwv73.5.mxl_chunk_6...
# Procesing bwv73.5.mxl_chunk_7...
# Procesing bwv73.5.mxl_chunk_8...
# Procesing bwv73.5.mxl_chunk_9...
# Procesing bwv74.8.mxl_chunk_0...
# Procesing bwv74.8.mxl_chunk_1...
# Procesing bwv74.8.mxl_chunk_10...
# Procesing bwv74.8.mxl_chunk_11...
# Procesing bwv74.8.mxl_chunk_2...
# Procesing bwv74.8.mxl_chunk_3...
# Procesing bwv74.8.mxl_chunk_4...
# Procesing bwv74.8.mxl_chunk_5...
# Procesing bwv74.8.mxl_chunk_6...
# Procesing bwv74.8.mxl_chunk_7...
# Procesing bwv74.8.mxl_chunk_8...
# Procesing bwv74.8.mxl_chunk_9...
# Procesing bwv77.6.mxl_chunk_0...
# Procesing bwv77.6.mxl_chunk_1...
# Procesing bwv77.6.mxl_chunk_10...
# Procesing bwv77.6.mxl_chunk_2...
# Procesing bwv77.6.mxl_chunk_3...
# Procesing bwv77.6.mxl_chunk_4...
# Procesing bwv77.6.mxl_chunk_5...
# Procesing bwv77.6.mxl_chunk_6...
# Procesing bwv77.6.mxl_chunk_7...
# Procesing bwv77.6.mxl_chunk_8...
# Procesing bwv77.6.mxl_chunk_9...
# Procesing bwv78.7.mxl_chunk_0...
# Procesing bwv78.7.mxl_chunk_1...
# Procesing bwv78.7.mxl_chunk_10...
# Procesing bwv78.7.mxl_chunk_11...
# Procesing bwv78.7.mxl_chunk_12...
# Procesing bwv78.7.mxl_chunk_2...
# Procesing bwv78.7.mxl_chunk_3...
# Procesing bwv78.7.mxl_chunk_4...
# Procesing bwv78.7.mxl_chunk_5...
# Procesing bwv78.7.mxl_chunk_6...
# Procesing bwv78.7.mxl_chunk_7...
# Procesing bwv78.7.mxl_chunk_8...
# Procesing bwv78.7.mxl_chunk_9...
# Procesing bwv80.8.mxl_chunk_0...
# Procesing bwv80.8.mxl_chunk_1...
# Procesing bwv80.8.mxl_chunk_10...
# Procesing bwv80.8.mxl_chunk_2...
# Procesing bwv80.8.mxl_chunk_3...
# Procesing bwv80.8.mxl_chunk_4...
# Procesing bwv80.8.mxl_chunk_5...
# Procesing bwv80.8.mxl_chunk_6...
# Procesing bwv80.8.mxl_chunk_7...
# Procesing bwv80.8.mxl_chunk_8...
# Procesing bwv80.8.mxl_chunk_9...
# Procesing bwv81.7.mxl_chunk_0...
# Procesing bwv81.7.mxl_chunk_1...
# Procesing bwv81.7.mxl_chunk_2...
# Procesing bwv81.7.mxl_chunk_3...
# Procesing bwv81.7.mxl_chunk_4...
# Procesing bwv81.7.mxl_chunk_5...
# Procesing bwv81.7.mxl_chunk_6...
# Procesing bwv81.7.mxl_chunk_7...
# Procesing bwv81.7.mxl_chunk_8...
# Procesing bwv81.7.mxl_chunk_9...
# Procesing bwv83.5.mxl_chunk_0...
# Procesing bwv83.5.mxl_chunk_1...
# Procesing bwv83.5.mxl_chunk_2...
# Procesing bwv83.5.mxl_chunk_3...
# Procesing bwv83.5.mxl_chunk_4...
# Procesing bwv83.5.mxl_chunk_5...
# Procesing bwv83.5.mxl_chunk_6...
# Procesing bwv83.5.mxl_chunk_7...
# Procesing bwv83.5.mxl_chunk_8...
# Procesing bwv83.5.mxl_chunk_9...
# Procesing bwv84.5.mxl_chunk_0...
# Procesing bwv84.5.mxl_chunk_1...
# Procesing bwv84.5.mxl_chunk_2...
# Procesing bwv84.5.mxl_chunk_3...
# Procesing bwv84.5.mxl_chunk_4...
# Procesing bwv84.5.mxl_chunk_5...
# Procesing bwv84.5.mxl_chunk_6...
# Procesing bwv85.6.mxl_chunk_0...
# Procesing bwv85.6.mxl_chunk_1...
# Procesing bwv85.6.mxl_chunk_10...
# Procesing bwv85.6.mxl_chunk_2...
# Procesing bwv85.6.mxl_chunk_3...
# Procesing bwv85.6.mxl_chunk_4...
# Procesing bwv85.6.mxl_chunk_5...
# Procesing bwv85.6.mxl_chunk_6...
# Procesing bwv85.6.mxl_chunk_7...
# Procesing bwv85.6.mxl_chunk_8...
# Procesing bwv85.6.mxl_chunk_9...
# Procesing bwv86.6.mxl_chunk_0...
# Procesing bwv86.6.mxl_chunk_1...
# Procesing bwv86.6.mxl_chunk_2...
# Procesing bwv86.6.mxl_chunk_3...
# Procesing bwv86.6.mxl_chunk_4...
# Procesing bwv86.6.mxl_chunk_5...
# Procesing bwv86.6.mxl_chunk_6...
# Procesing bwv86.6.mxl_chunk_7...
# Procesing bwv86.6.mxl_chunk_8...
# Procesing bwv87.7.mxl_chunk_0...
# Procesing bwv87.7.mxl_chunk_1...
# Procesing bwv87.7.mxl_chunk_2...
# Procesing bwv87.7.mxl_chunk_3...
# Procesing bwv87.7.mxl_chunk_4...
# Procesing bwv87.7.mxl_chunk_5...
# Procesing bwv87.7.mxl_chunk_6...
# Procesing bwv87.7.mxl_chunk_7...
# Procesing bwv87.7.mxl_chunk_8...
# Procesing bwv87.7.mxl_chunk_9...
# Procesing bwv88.7.mxl_chunk_0...
# Procesing bwv88.7.mxl_chunk_1...
# Procesing bwv88.7.mxl_chunk_2...
# Procesing bwv88.7.mxl_chunk_3...
# Procesing bwv88.7.mxl_chunk_4...
# Procesing bwv88.7.mxl_chunk_5...
# Procesing bwv88.7.mxl_chunk_6...
# Procesing bwv89.6.mxl_chunk_0...
# Procesing bwv89.6.mxl_chunk_1...
# Procesing bwv89.6.mxl_chunk_10...
# Procesing bwv89.6.mxl_chunk_2...
# Procesing bwv89.6.mxl_chunk_3...
# Procesing bwv89.6.mxl_chunk_4...
# Procesing bwv89.6.mxl_chunk_5...
# Procesing bwv89.6.mxl_chunk_6...
# Procesing bwv89.6.mxl_chunk_7...
# Procesing bwv89.6.mxl_chunk_8...
# Procesing bwv89.6.mxl_chunk_9...
# Procesing bwv9.7.mxl_chunk_0...
# Procesing bwv9.7.mxl_chunk_1...
# Procesing bwv9.7.mxl_chunk_2...
# Procesing bwv9.7.mxl_chunk_3...
# Procesing bwv9.7.mxl_chunk_4...
# Procesing bwv9.7.mxl_chunk_5...
# Procesing bwv9.7.mxl_chunk_6...
# Procesing bwv9.7.mxl_chunk_7...
# Procesing bwv90.5.mxl_chunk_0...
# Procesing bwv90.5.mxl_chunk_1...
# Procesing bwv90.5.mxl_chunk_10...
# Procesing bwv90.5.mxl_chunk_2...
# Procesing bwv90.5.mxl_chunk_3...
# Procesing bwv90.5.mxl_chunk_4...
# Procesing bwv90.5.mxl_chunk_5...
# Procesing bwv90.5.mxl_chunk_6...
# Procesing bwv90.5.mxl_chunk_7...
# Procesing bwv90.5.mxl_chunk_8...
# Procesing bwv90.5.mxl_chunk_9...
# Procesing bwv92.9.mxl_chunk_0...
# Procesing bwv92.9.mxl_chunk_1...
# Procesing bwv92.9.mxl_chunk_10...
# Procesing bwv92.9.mxl_chunk_11...
# Procesing bwv92.9.mxl_chunk_12...
# Procesing bwv92.9.mxl_chunk_13...
# Procesing bwv92.9.mxl_chunk_14...
# Procesing bwv92.9.mxl_chunk_15...
# Procesing bwv92.9.mxl_chunk_2...
# Procesing bwv92.9.mxl_chunk_3...
# Procesing bwv92.9.mxl_chunk_4...
# Procesing bwv92.9.mxl_chunk_5...
# Procesing bwv92.9.mxl_chunk_6...
# Procesing bwv92.9.mxl_chunk_7...
# Procesing bwv92.9.mxl_chunk_8...
# Procesing bwv92.9.mxl_chunk_9...
# Procesing bwv93.7.mxl_chunk_0...
# Procesing bwv93.7.mxl_chunk_1...
# Procesing bwv93.7.mxl_chunk_10...
# Procesing bwv93.7.mxl_chunk_11...
# Procesing bwv93.7.mxl_chunk_2...
# Procesing bwv93.7.mxl_chunk_3...
# Procesing bwv93.7.mxl_chunk_4...
# Procesing bwv93.7.mxl_chunk_5...
# Procesing bwv93.7.mxl_chunk_6...
# Procesing bwv93.7.mxl_chunk_7...
# Procesing bwv93.7.mxl_chunk_8...
# Procesing bwv93.7.mxl_chunk_9...
# Procesing bwv94.8.mxl_chunk_0...
# Procesing bwv94.8.mxl_chunk_1...
# Procesing bwv94.8.mxl_chunk_10...
# Procesing bwv94.8.mxl_chunk_11...
# Procesing bwv94.8.mxl_chunk_12...
# Procesing bwv94.8.mxl_chunk_13...
# Procesing bwv94.8.mxl_chunk_14...
# Procesing bwv94.8.mxl_chunk_2...
# Procesing bwv94.8.mxl_chunk_3...
# Procesing bwv94.8.mxl_chunk_4...
# Procesing bwv94.8.mxl_chunk_5...
# Procesing bwv94.8.mxl_chunk_6...
# Procesing bwv94.8.mxl_chunk_7...
# Procesing bwv94.8.mxl_chunk_8...
# Procesing bwv94.8.mxl_chunk_9...
# Procesing bwv96.6.mxl_chunk_0...
# Procesing bwv96.6.mxl_chunk_1...
# Procesing bwv96.6.mxl_chunk_2...
# Procesing bwv96.6.mxl_chunk_3...
# Procesing bwv96.6.mxl_chunk_4...
# Procesing bwv96.6.mxl_chunk_5...
# Procesing bwv96.6.mxl_chunk_6...
# Procesing bwv96.6.mxl_chunk_7...
# Procesing bwv99.6.mxl_chunk_0...
# Procesing bwv99.6.mxl_chunk_1...
# Procesing bwv99.6.mxl_chunk_10...
# Procesing bwv99.6.mxl_chunk_2...
# Procesing bwv99.6.mxl_chunk_3...
# Procesing bwv99.6.mxl_chunk_4...
# Procesing bwv99.6.mxl_chunk_5...
# Procesing bwv99.6.mxl_chunk_6...
# Procesing bwv99.6.mxl_chunk_7...
# Procesing bwv99.6.mxl_chunk_8...
# Procesing bwv99.6.mxl_chunk_9...

# %%
x = np.array(x)
y = np.array(y)

# %%
np.save('input.npy', x)
np.save('output.npy', y)
